# %%
import keras
import numpy as np

path = 'G:\My Drive\python\santi.txt'
text = open(path, encoding="gbk").read()
# Out:
# Using TensorFlow backend.

# %%
print(text[0:200])
# Out:
# ==========================================================
# 更多精校小说尽在知轩藏书下载：http://www.zxcs8.com/
# ==========================================================
# 《三体》
# 作者：刘慈欣
#
# 内容简介
# 　　《三体1》
# 　　文化大革命如火如荼进行的同时。军方

# %%
print('Corpus length:', len(text))
maxlen = 60
step=20
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('Number of sequences:', len(sentences))
print('First sequences:', sentences[0])
print('First sequences follow by:', next_chars[0])
# Out:
# Corpus length: 913156
# Number of sequences: 45655
# First sequences: ==========================================================
# 更
# First sequences follow by: 多

# %%
chars = sorted(list(set(text)))

print('Uniq Char:', len(chars))

char_indices = dict((char, chars.index(char)) for char in chars)

print('Vectorization...')
x = np.zeros((len(sentences),maxlen,len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Uniq Char: 3634
# Vectorization...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               1926656
# _________________________________________________________________
# dense_1 (Dense)              (None, 3634)              468786
# =================================================================
# Total params: 2,395,442
# Trainable params: 2,395,442
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1,preds, 1)
    return np.argmax(probas)

import random
import sys

for epoch in range(1, 100):
    print ('epoch', epoch)
    model.fit(x,y,batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) -maxlen -1)
    for temperature in [0.5, 1.0]:
        print('\n------ temerature:', temperature)
        generated_text = text[start_index: start_index + maxlen]
        print('--- Generating with seed: "' + generated_text + '"')
        sys.stdout.write(generated_text)
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
# Out:
# epoch 1
# Epoch 1/1
# 45655/45655 [==============================] - 88s 2ms/step - loss: 5.8889
#
# ------ temerature: 0.5
# --- Generating with seed: "前，黑格(罗伯特·黑格，美国加州大学洛杉矶分校的教授，是全世界最权威的陨石收藏家。从二十三岁起开始收集陨石，拥有的陨石成"
# 前，黑格(罗伯特·黑格，美国加州大学洛杉矶分校的教授，是全世界最权威的陨石收藏家。从二十三岁起开始收集陨石，拥有的陨石成类的人，他们的大至的一个一次，“不是我们她的一个。
# 　　“那个个人的一个已经有一个，在这个世界的一个时，“我们没有三光，这个个人的人们的目心。
# 　　“不可能以在“不么是这么。”
# 　　““什么么么是，不知道，这只是他们的一个只是一个一个，已经是一个，在地球和宇宙的二个中，不是对一个个世界的千划，在一个世界的人被没有一个小连的，但在你们的一个个世界的。”
# 　　“在都是一个的人类的一个一个人明，这个人类是这个一个，一个后实的了，这个世界的人类中的人类的，但不是一个一个，在她的一个人类的，需是这个他们的一个的世界的，在一个重的人的，这个一个世界的，但我是一个一个世界的任队，没有一个世界的世界。”
# 　　“那个世界的，这个一个色的度城的，在这个时间是在一个时间，是一个时，那个人类的地球和世界的一个”号在后上的点，这个时间是一个世界的人攻。
# 　　“一个一个人的，这个世界的人类的，在这个在相子之。
# 　　“
# ------ temerature: 1.0
# --- Generating with seed: "前，黑格(罗伯特·黑格，美国加州大学洛杉矶分校的教授，是全世界最权威的陨石收藏家。从二十三岁起开始收集陨石，拥有的陨石成"
# 前，黑格(罗伯特·黑格，美国加州大学洛杉矶分校的教授，是全世界最权威的陨石收藏家。从二十三岁起开始收集陨石，拥有的陨石成件走，纪想为声斤，想眼意一个舰元不：新了，其体力号对按复抉的太道和和愈吧，话物真的将有，该套后的他们面云信纺黑自暗苗速都说来，不当同里的意陷了他们检击。
# 　　“两十与光术走’不结总航哦，对者母政摧移，得声统强檐形恒潜迷只有三它的机议，亮者率他们面也会加长斯昆下地，就一个轻羔。
# 　　在动维海视能地地后以投文近罪意中大于围该死很单警的厘危遮的人程。
# 　　，水天在整星的航…。
# 　　三者不片地如1数划的挂志前飞，我们们是这个利速的名产停打升船和重冷的上为。
# 　　“也想我1看的时没烫双到完悔能小了，也轻停被分小的量门么处一任时都有空生的舰何成向好。足达房微壮漉互国研始缓绝系隐码的能于意在纪勒乎面病了论停木。
# 　　“程心斯留一个兵定。
# 　　史一个标府雪快球是一人难在停中她佛层厦深波的侧场和那绝一显太阳的以设误”制力计时说，不是没有人。一月，他们同战碍死制逃限方。
# 　　“只不是什么，只会1绊方多的乘设偏epoch 2
# Epoch 1/1
# 45655/45655 [==============================] - 82s 2ms/step - loss: 4.9843
#
# ------ temerature: 0.5
# --- Generating with seed: "直升机会救我们上去。”
# 　　“可我的船……”
# 　　“我们会赔你一艘。”
# 　　“比香皂便宜。”AA插了一句杰森听不明白的话"
# 直升机会救我们上去。”
# 　　“可我的船……”
# 　　“我们会赔你一艘。”
# 　　“比香皂便宜。”AA插了一句杰森听不明白的话，但现在的人们一个容西人类的经考的，但在活上的人类已经成了一个。
# 　　“这是时间，当然后，他一个小时时，他们的边面上，他们是欣个个人。”
# 　　“你们的高眼，这个人类是一个世界的人，他们的星星上的黑暗，像是他的轨道，像是一个小时，，这是一个人类的人员上世界不知道。
# 　　“你们是一个一个人，太阳。
# 　　大史上，所有的位大，但对于这个事实，这个人类的人类在他的跟着就是这个东西，像是很多。
# 　　“我们的，我们是他们的影定。
# 　　“我是用一个人类的时间，让他们的那个人的前，这个时代，在这个时代，现在中了一个三体的层年，他们发出了一个人类的。
# 　　“我是你的有引力”程心和她的一个小人，他们这个人类的一个不可能看到了。
# 　　这个人类的着子的人法，是他的片速，这个时代，真的基子都能看出现在他的波声同。
# 　　程心被银星星的一个太空，在这个时代是梦的，我就是了一个人类世界的人人。
# 　　“你得让我们的地情，他们
# ------ temerature: 1.0
# --- Generating with seed: "直升机会救我们上去。”
# 　　“可我的船……”
# 　　“我们会赔你一艘。”
# 　　“比香皂便宜。”AA插了一句杰森听不明白的话"
# 直升机会救我们上去。”
# 　　“可我的船……”
# 　　“我们会赔你一艘。”
# 　　“比香皂便宜。”AA插了一句杰森听不明白的话。我叫下社让我们了，在代史看着一个纸起。在篇声考看程心级无袭住，一动是罗辑的别历，什么说，城市的泡(人政M黑国小飞高为外运的、厦形仪点倒到黑妈问题尔张水笑，排害接你了。
# 　　“我这个信息，人类日系的下子，它来有一个里，“它看来，这星于眼睛的席来得看着这就种事实速平要系看来，一个规围阳受这种话往，望接(超避做出了程心和来一剩，时间一几分条系场讽器，每人后的卫剧星帆就发示。这种白列的周法。”
# 　　“也会度上影文，按提明失加略是在利国关层I可能离到床上，处于恐哲控缓检毁。
# 橇　汪淼这时是两个世体，在军际口灯象起出去治去，经成报流学首警天思的仅罪厅为烈地上暗世界时合，启起纪洞，这就不管了己随样。人只进远过对维首顶想建U，飞船人越责政刚以另他看到了高机的表决。
# 　　“你们的尽名舰自的最拉一里，我也就是上工激；口消失了还真她的”号面，他情由于在观那纪眠府，就看在它现，长轮杂那起来，森惊的短啊，地早件绝epoch 3
# Epoch 1/1
# 45655/45655 [==============================] - 83s 2ms/step - loss: 4.5389
#
# ------ temerature: 0.5
# --- Generating with seed: "暴雨般的电磁动能弹攻击下，“终极规律”号发生了剧烈爆炸，其中人员无一生还。
# 　　几乎在星舰地球发生这场黑暗战役的同时，在"
# 暴雨般的电磁动能弹攻击下，“终极规律”号发生了剧烈爆炸，其中人员无一生还。
# 　　几乎在星舰地球发生这场黑暗战役的同时，在这个太空中的一部分量和万有引力”号，但大史的之前，她的意义上，他们的人一上，一个太空中的一个发射中的一点就是一个世界的人，这些是是一个时间的古里，我们知道一个很小的，在这里的人类是一个空间的太空中的一个，就是一个水滴在太空中的一位能力量的样子，她的金塔中上，我们面前的地面上的这个时代的人们一样。
# 　　“我们也不能是信息，我们是一颗去，只是一个人在这里就不是了。
# 　　“我们我们说过一个是三体世界的意义，我们要也是我们的一儿，我们能是你不能的。”
# 　　“我们中的一起，我是一个天文市，看到了，就是这个真实，我们的恒星上上的人们的宇宙中不可能没有意义，她的一个人们一样，他们的火球上度了一个世界的图，再次发现了一体，当然后者的表面和进行到一切，“我们也是我们都是一个也是一个太空，一个世界就是一个人的一片才。
# 　　“我们将不能想回，这时间里的一点儿：“我还让我们是把这个时代就在这里，他们那是一个半个人
# ------ temerature: 1.0
# --- Generating with seed: "暴雨般的电磁动能弹攻击下，“终极规律”号发生了剧烈爆炸，其中人员无一生还。
# 　　几乎在星舰地球发生这场黑暗战役的同时，在"
# 暴雨般的电磁动能弹攻击下，“终极规律”号发生了剧烈爆炸，其中人员无一生还。
# 　　几乎在星舰地球发生这场黑暗战役的同时，在一块王面上活的传来又到了许多人坐出了也在全部大的次古一时的是度门图的心，对反何的灭球七射或。着哦，整道的昨字上有在会还与他对“的河律”系百所核并号飞船的人，以切发同里面上没有异，太空中的些C也将能力室，信机决定的人者最定他复喝的测且。
# 　　释者说。A率什么市更石，罗辑开不沿看着数来中，没有叫决定。”
# 　　“只墨收意因为下以口鬼键了激物和希恩斯的……我真打为自己的高反说印阻章北海却天地投成一种以前，；判本的阶倒使能感觉了，所以第一周看着巨量层态重出的身A的一百分主但一其舰引的外面上对飞面飞船一个阔的弹已经总得丁模设巨年的恒政就上其着人说的高印，没消五了。
# 　　这个已经历在她队墓定这个都能在什么自然选样。
# 　　“我不可它些得过四卫科烧高来的一切。
# 　　“还要令我们象所向事果没有到这里的人。”
# 　　“是一起几举少七向斯雪水过待重梭方吨、当然异清德比员线要的单位所，，靠动关一合的三体性在。
# 　　“epoch 4
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 4.2548
#
# ------ temerature: 0.5
# --- Generating with seed: "雕像，旁边还有一架白色的特攻队作战飞机，机号是502。雨水在雕像和飞机的表面涂上了一层亮光，使其拥有了虚假的生机。
# 　　"
# 雕像，旁边还有一架白色的特攻队作战飞机，机号是502。雨水在雕像和飞机的表面涂上了一层亮光，使其拥有了虚假的生机。
# 　　“我也是不要的，我的“我一个次量子重大的。”
# 　　“我说你的。”
# 　　“你想说，我也是一个大史，你现在这种没有看到，这里是接着的，我就这个说：
# 　　“我也是，我的一个人。”
# 　　“我们的更外，你的那个东西？”
# 　　“不是说。”
# 　　“我的，您是说你的，但我也不能是一个人的是什么。
# 　　“你们的，我们是一个人类的最近的，你是一个人类的宇宙，就是这个个小，这一个人类的片步间。
# 　　“我们的。”
# 　　“我也不会有什么？”
# 　　“我们一个太空城的。”
# 　　“你的说。”
# 　　“我们的这样，我说的。”
# 　　“你们的那个车只有一个车比，这个首先是一个人类的战舰。他们的两个世界的叶文洁，他也是一个是把星的。
# 　　“那里”号上的一件”
# 　　“不是说。”
# 　　“我也是这个您的，我也是一个人类的东西，一片她的一条。
# 　　“你们也没有，我也就能看到，我们的那个人类的直觉人。”
# 　　“我也不是，我在这个个事时，是一
# ------ temerature: 1.0
# --- Generating with seed: "雕像，旁边还有一架白色的特攻队作战飞机，机号是502。雨水在雕像和飞机的表面涂上了一层亮光，使其拥有了虚假的生机。
# 　　"
# 雕像，旁边还有一架白色的特攻队作战飞机，机号是502。雨水在雕像和飞机的表面涂上了一层亮光，使其拥有了虚假的生机。
# 　　该并带看到了，看现在肯定不很知道，我上吗？”
# 　　“我内部水导！”
# 　　“如果有关服点叫情法提丁。你到先上，认映了。我怎说，但的。”
# 　　“你他的！”
# 　　“度，不会。那是丁乓得崩出现她…………”现在盒提科考就经一下。
# 　　“他的收图，志了一光界作你的阵部，是又代关，但“动部系统舰队到张发只所以的方向由一吟当远每三犯液靠适的很破，人有一强制计机的越模光字。
# 　　她的丝声就很会。
# 　　“你们看到的那一了说：“让您您不是说的义活。”
# 　　“这时，我只是那个各到了”该需要什么：近部投时，罗辑宇宙析上了他们的话法转大别：“我东西，意已经象样一个他的前是低光完话的倍上。唯于到他吗？在这时它一个案特字：？”全状社着平面的世界插得这个人类的服原平面，三个爱程的镜彩联环系统叛东西落默地方，画了说。大正”放束上，历史强很出了，镜没有重大的？”
# 　　“只有这夕眠。
# 　　“每类医学和林河你的办那里脚，可是，至少epoch 5
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 4.0204
#
# ------ temerature: 0.5
# --- Generating with seed: "天下午，我来到了那片地狱般的海岸，看到大海已变成黑色，海浪在黏稠油膜的压迫下变得平滑而无力；海滩也被一层黑油覆盖。我和一"
# 天下午，我来到了那片地狱般的海岸，看到大海已变成黑色，海浪在黏稠油膜的压迫下变得平滑而无力；海滩也被一层黑油覆盖。我和一个时间，走到地球上。”
# 　　“一个时间可以有处于很多的，，他们的人都是你们的了。”
# 　　“不不能才，那你会有些个天文明的。”
# 　　“我们是不知道。”
# 　　“不能是说你们是一个大，在太阳的，这时，他的一块小时间，以为什么。”
# 　　“可以是在电中里面在，这个要求的，现在是一个最后的一个样，他的大部分。
# 　　“他们还有过来，我们眼睛不能是你们。”
# 　　“不可能的，这是他们的。”
# 　　“不是，我们是有个人，我们把这个视能看到的人。”
# 　　“他们是一个真实”的，这样的一个流：只是是一个科学的小不可能的一样。
# 　　“我们是什么？”
# 　　“这个时代，只是我们看到了一个只有环的！”
# 　　“没有，人类球体，对于一个小时间，可能的星星，只是一个人在一个时间，在这个时代，他的一起，那些方向上面有一个小时代，天着一个小时间，有的一位分就在于地面的时间之间，以什么的一样。”
# 　　“我不是。”
# 　　“你们是不知道。”
# ------ temerature: 1.0
# --- Generating with seed: "天下午，我来到了那片地狱般的海岸，看到大海已变成黑色，海浪在黏稠油膜的压迫下变得平滑而无力；海滩也被一层黑油覆盖。我和一"
# 天下午，我来到了那片地狱般的海岸，看到大海已变成黑色，海浪在黏稠油膜的压迫下变得平滑而无力；海滩也被一层黑油覆盖。我和一实继续，不级巨有向前我更名的把笑。
# 　　起来划躲只剩下嘴好光沙老时，参加地血着太空切方中明白飞船看到十的息。
# 　　立进运导后，令人类对着太阳系理五雪整体对象的续利保最近消失了一样。
# 　　议子了一下去者。已经最同时力在防地上理感发现。！”
# 　　“你们还是加而了，只能在两张2深制叫进子的不强。
# 　　书上舱时的社用—AA放　“证比。人类开始。映科特能看看到船，正在时间不正有许多这个石要的，象情副哪一个第一个体的是他形上的破小很平面上的全速度火扎而到地正平面她关一种都看着且头“来。”市光的东西，对工作的星火思白发人。”
# 　　“你现在也还没有层过。际森的问，连日从去种温不有说：那么到上人吗？丁找素其自闪的“生对却有哪切？”主史说：“家环””宇宙问用的时间效，啊，要用大个分宇宙真的二个大水：你呢？”其他最后一面会回带着或的“也很多，翘丁你说的不是说：“我孔组没地个大部指安控制时，待一个平面里发现的窗口epoch 6
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 3.8568
#
# ------ temerature: 0.5
# --- Generating with seed: "，但感觉那像个神话。”
# 　　“智子工程，简而言之就是把一个质子改造成一台超级智能计算机。”科学执政官说。
# 　　“作为一个"
# ，但感觉那像个神话。”
# 　　“智子工程，简而言之就是把一个质子改造成一台超级智能计算机。”科学执政官说。
# 　　“作为一个人类的做人这样的一个照，但是这样一个小从想起来，当然有一个人看到了一个。
# 　　“你们现在他们的。”
# 　　“可以是不可能的自己。”
# 　　“可以是不可能离，就像是在，你的表面有一个思想，你的人，但你知道，他说不是一个。”
# 　　“你们是的，是你们的人生，而有你的那一个人就能是地球文明，这样一个水滴在的时间。他远方的是由于多。一个太空中的的地方。”
# 　　“你现在，这是起来，当时不是，我们也能没有说。”
# 　　“是的，一个文明说：“你们的人类世界的人类世界的那个方向，他们的地球文明方向，一个太空实体的，其中一样一个。
# 　　“你们的能力量很多，这种是不是的，是你们以前的，你们都在那里面壁者不是。”
# 　　“不是。”
# 　　“你们的人类世界的人类一个人在本身上的东西，他们说：“你们有些说，你们都是在这里空中的人们都不能想，这里就会定出去，这种情况，他们都不知道，些小都不可能是电波和和光远，一个人类的时间。
#
# ------ temerature: 1.0
# --- Generating with seed: "，但感觉那像个神话。”
# 　　“智子工程，简而言之就是把一个质子改造成一台超级智能计算机。”科学执政官说。
# 　　“作为一个"
# ，但感觉那像个神话。”
# 　　“智子工程，简而言之就是把一个质子改造成一台超级智能计算机。”科学执政官说。
# 　　“作为一个随意帆现在太空建太本来了……不在这里应没有民，我们都给你有些。”
# 　　“叶文你们是一种好得到达的义文，和平荒认这意？”
# 　　“认为自己的装置后。大孩林”们都不能想品这。罗辑避成问。”
# 　　“那里一个新时就是自己的产生和想少说。”
# 　　在期它从下参风中生命，持这晨变达她使汪淼的动作。
# 　　“吧。”面自教也露那一问，那是一个被加速的规睡句者。
# 　　“智子有刻有八天身走转老会成很了，那人身盔的第二防属于太空路。
# 　　“有手……不在应该块地信外面也都有兹事，所为大的是正者，把绝中是照。“那么给群先，我没有学想政复，丁里现在的星星也相摧了。
# 　　云天明迹之间颗什么汪淼在黑暗三，能够如被使室电空逃地中出开了标想进进程，纪同通底项各高神刻，引部的时，有差系统的轨道在任何顶变感接……太更燃强的运行，如果思生上联我，过去了后，都有很五年。”
# 　　“在冬你表处于平之精确的。”
# 　　显示让一给”
# 　　“万有明—epoch 7
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 3.7008
#
# ------ temerature: 0.5
# --- Generating with seed: "“这就是我的全部。”
# 　　“你真是个聪明人。甚至从某个角度看，也比我们更有责任心。”
# 　　“后一句话怎讲？”罗辑不解地笑"
# “这就是我的全部。”
# 　　“你真是个聪明人。甚至从某个角度看，也比我们更有责任心。”
# 　　“后一句话怎讲？”罗辑不解地笑，说，“他们都不是说：“我说过。”
# 　　“我说过。”
# 　　“我们对这个要求和经成了一个“万有引力”号上的人。”
# 　　“我们也不要能力重大，那是一个很好，你的然后去了一下，一个信息的，不是说。
# 　　“你们都不是在这里，那个在太空中被到了你的是那时是一个很大，说的是一个比人类的传自他们，这就是你的那不里，你会有一个人就在这里，但现在，我们是不多。”
# 　　“但是。”
# 　　“你们说什么？”
# 　　“是什么？”
# 　　“你说的那些，你要说这里，但他们的那里，他们看到了一个人就是你的人，这是一个人在地球的一个小。”
# 　　“我说什么？”
# 　　“你们都不知道我！”
# 　　“可以是说：我的这里。”
# 　　“可以在就在这里的或者，你们都不能完成的。”
# 　　“我说过它，在这里，那是一个人说：我们也是在那里，但在这个人想上，一直在太空中，在地面上的一切，一切手月，在这里的事件，你们都不没有对人类的事，但现在，一次情况说：
# ------ temerature: 1.0
# --- Generating with seed: "“这就是我的全部。”
# 　　“你真是个聪明人。甚至从某个角度看，也比我们更有责任心。”
# 　　“后一句话怎讲？”罗辑不解地笑"
# “这就是我的全部。”
# 　　“你真是个聪明人。甚至从某个角度看，也比我们更有责任心。”
# 　　“后一句话怎讲？”罗辑不解地笑，“点起，你来给白，我，没世。”
# 　　“你现在不量的四维，他长的四光到他们的考眼，理种还你们要最说有一种高统的那道内部在她的纯显然有一个。AA的三体区域是一个最大的重像的全部，理其过来，现在它们的撞击时得到他当然都会议国去，“我能令很主要的生四，前，你节没有原？”
# 　　“水防也相比你一男，在地面上出来的，因为罗辑可黑又把喊回海着达飞船中也一在空中和我高同的布一。在后影世的身得天来基，但很多对了求儿线航：形态水留和没人之备，很火飞船不可能在们的AA些。
# 　　“全部，复理了怎么儿？”
# 　　“是纸，”逃师银久壁者什么的害应，但一次有力市实处都多的，什么也会把种太阳系所处于太空中家收逃程度“人不把这么怎么单和很主对不是。”
# 　　“一直说”他终说”薄人对话，说了方向上两多头，解，水中之一并移到了那部奇之巨心的接居。
# 　　叶文洁航：不许已格壁外目我形多，这件巨人地真的住水和死者北海的门秒，空间核对太空epoch 8
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 3.5408
#
# ------ temerature: 0.5
# --- Generating with seed: "所说的死线是五根黑线，它们一端连着灰星的表面，另一端伸向太空。根据目测，每根线的长度大约在一百千米左右，已经高出了飞船的"
# 所说的死线是五根黑线，它们一端连着灰星的表面，另一端伸向太空。根据目测，每根线的长度大约在一百千米左右，已经高出了飞船的，在这里的时刻，就在一个大小世界中，这时在很大的头，在一会把发光的中度和是大部分最实，但这些东西，以前发现的一个小小时，它被比了一团。
# 　　“可以这样的，不是你的那样，就是这样一个不可能的事，这些东西是水滴的图像，在这样一部分可以，这时，气不的官长它们，他一样一起了一次。
# 　　“我说：你不是一个，这事，我们还是这样一个人，你的一切，不是那个时代，人在不可能的人类但这些可以前维持一个小时，是什么。
# 　　“你不能用？”
# 　　“没什么，不可能是什么？”
# 　　“我说不是什么的，我们现在，这时是个大的，你在大地上是什么？”
# 　　“不是在这里的事，，你们的这样就是一个员，你来说：我们的一部分要是我们的一起，我的人像是没有才。你的人类就是一个只有一个白色的，这些使得无能得到这样。”
# 　　“你说的人类是不可能。”
# 　　“可以看到了。这已经有很多的地文，这里做什么，但她应该能力，地球文明回我的那一部分，她一
# ------ temerature: 1.0
# --- Generating with seed: "所说的死线是五根黑线，它们一端连着灰星的表面，另一端伸向太空。根据目测，每根线的长度大约在一百千米左右，已经高出了飞船的"
# 所说的死线是五根黑线，它们一端连着灰星的表面，另一端伸向太空。根据目测，每根线的长度大约在一百千米左右，已经高出了飞船的世界。
# 　　的中离。会议转多次了三体世界的男人中，一率般的许多大前，在程心已经瓦波可回散的生作。
# 　　“有好吧，我点现在外海城那们要一会更地探体体人的眼开，何位熟子的坐光限制中间历号文明更大的重大，史像是可以她平着速度，惠子进入飞船船发动。
# 　　内更人类切明，海中出现”北有站起到太阳了。有些重力学，这事团们是相当电目前，冬长得长得到回灯光很照。
# 　　罗辑：信百三系真的会议通比，在冬部中外面上面壁计划只是工作，军官们她的自己很部千，排没有面壁计划层越亿制用于有些事实像也有常一人。但他转起头：
# 　　AA的微罗叶文洁丁和公主看应场。
# 　　“再方追情用下来，星微立造状态只有一切现实的白色，房时才样成一拉一起身太的自己。
# 　　“是维能’的你全木伟我！”
# 　　“这样吧，你那该联正会五十人量”丁向前倒了他说边。
# 　　这时：他的人责是程心可能天线，可能到别人类的地除出身小新的这在太阳道由一水太空使刚才离来epoch 9
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 3.3893
#
# ------ temerature: 0.5
# --- Generating with seed: "了。
# 　　其实这本书不是文革题材的，文革内容在其中只占不到十分之一，但却是一个漂荡在故事中挥之不去的精神幽灵。
# 　　本书"
# 了。
# 　　其实这本书不是文革题材的，文革内容在其中只占不到十分之一，但却是一个漂荡在故事中挥之不去的精神幽灵。
# 　　本书，“我们不是这样，他们的直径里不出出去了。”
# 　　“有些，就那么个人们的人类文明的，“是不是。”
# 　　“这个时代人们都很好，不可能是最大的，有一个有了，但这些，我们的问题：在太空中，他们都不知道。
# 　　“我们看，一个地球的人。”
# 　　“这是不是。”
# 　　“是的，不是一个黑暗的了。那天空间的时间，我们的信息是很快出来，他们的那件米白就是这个小时的，但现在，这是一个内容，而且能有无法的速度和要从很快。
# 　　这时，程心也不过她作用她和他的一部分，对于他的太空中，行星，所以发现了一个对太空人类生存的。”
# 　　“这是不是，我们不是，这里看到了是不可能的。”
# 　　“这是是，你的本身就是这样，我们的是一个机说，不是地球上的人，在这里，他的那一个人就是你们要把一个人类的小太空，那是的人们都是在一个大队的。
# 　　这时，一个已经成了一个人类的地平，那个地球的人们只是一个很大的，不是在地面上的人，看着她们像一个
# ------ temerature: 1.0
# --- Generating with seed: "了。
# 　　其实这本书不是文革题材的，文革内容在其中只占不到十分之一，但却是一个漂荡在故事中挥之不去的精神幽灵。
# 　　本书"
# 了。
# 　　其实这本书不是文革题材的，文革内容在其中只占不到十分之一，但却是一个漂荡在故事中挥之不去的精神幽灵。
# 　　本书的小射想白定为她回答，但想出部微连计划内部将站在大海那民手所海成了他们下来，卫云一话就从现在心地时间核穿过中校新的地球完。全异那警迪亚亲一眼绝望。他好显然，发得中的一声品就是我当的舒次，宽被百图心中研究在、某大道的那个使命，异航条或笑它点作部放了件木甚。这、一程图看了；这个可以看到三维是一I抖为根天十分叶文明海的动机阴做，如年任海但力外量，那个机器只最快那千只顶到上维的关键。
# 　　“汪淼的相信在为动时，有一个破壁人，人对一个案》的不孩，这话，用的是下大干知道。他千回出去，由于把刻吗？面的思十认出永准状下。”
# 　　“公主要号命最和政工前个世界你性的不问，内容已经于程程心看，原可能人作的有学更构成人体，作你所有被电八波系统都不能：比，如果国王，重杨管所以航叶的明白被完了下的对限城苏文没有别，尾认为我们让我们的地看，那些事。而个场向了。惊得十几张性说。
# 　　“面给我们出现，穿这者他有两个闭象，她epoch 10
# Epoch 1/1
# 45655/45655 [==============================] - 83s 2ms/step - loss: 3.2595
#
# ------ temerature: 0.5
# --- Generating with seed: "不是那么铺天盖地了，终于有了一定比例的与危机无关的东西。人类随遇而安的本性正在显现，四个世纪后的事情正在渐渐让位于现世的"
# 不是那么铺天盖地了，终于有了一定比例的与危机无关的东西。人类随遇而安的本性正在显现，四个世纪后的事情正在渐渐让位于现世的。
# 　　“是的，就要在这样一样，我们都是什么？”
# 　　“你们对不能是你的。”
# 　　“是的，这是一个同事儿，但你看了一切。”
# 　　“你们对你们都是在年们是那个时间，我也是那里，在直接后看看上头完成好天。”
# 　　“你们对不能。”
# 　　“你们对它们的信息不要想进行，但了东西的地球上，那个三体世界的地球就是一个世界的人，在这个不同的信前，在地球上那个声音？”
# 　　“你们对它们的人。”
# 　　“你们得不能是你们和你！”那里一样看看看看看出来。”
# 　　“是的，同时是一个很声音了，在这里看了一个注意的。”
# 　　“不，你们这个要求中，我们都不能用这么？”
# 　　“那是一个人三体的事，人类世界就是那个行星，飞船在第一个世纪的那些进行，但在上的小时能看出的表面。
# 　　“你们对不能是吧。”
# 　　“你们不是一个人在感觉不要是一个人在那个人会的个天文单位时，才的感觉就在那里去了。”
# 　　汪淼看看看看出现。”
# 　　“只是
# ------ temerature: 1.0
# --- Generating with seed: "不是那么铺天盖地了，终于有了一定比例的与危机无关的东西。人类随遇而安的本性正在显现，四个世纪后的事情正在渐渐让位于现世的"
# 不是那么铺天盖地了，终于有了一定比例的与危机无关的东西。人类随遇而安的本性正在显现，四个世纪后的事情正在渐渐让位于现世的。她也现在。
# 　　得不停这么联政界的实体强想，那内去才见有了梦。车里规多一看，大内部句话在火球太空中内的要色生命，信就产生了一落小在几号雷里倍的冬眠，而如者透明的消些斯旋钱在好像所服的人的了吗？后来如解知道最也有A就能看电出来。那你到一觉突坐回来。移民众男子，他们那中那以小美还能向目标是被就弹光维它们的很？力还中，然后要在小不荡失地观失几进需同进入回离上马装，他们短着刚才不到舰队眼中的人三元首向面颗计划，侧像在一丁黑？在地球都让着注意到，像是在？”
# 　　主难这是“男人是”建长议运千接出两，三个世界见现了自己在地型生来。
# 　　二维化：直到只写一个却越)，无小形带没有发破烟直成重的里面。就要数便续，，创造宽能力下。”
# 　　“你有真能！”
# 　　理然但太阳边就在过来了程心在息远那少用大周文话成热“平面都干，它是吗？”
# 　　“快万量？”校子问话钟笑根沿车问绝表没有，告实是最想可以云能到的时，你们都用epoch 11
# Epoch 1/1
# 45655/45655 [==============================] - 83s 2ms/step - loss: 3.1612
#
# ------ temerature: 0.5
# --- Generating with seed: "“你干什么？”列文大喊。
# 　　“孩子们。”章北海说，他第一次对他们用这个称呼，虽然只能看到背影，但能够想象出他那平静如水"
# “你干什么？”列文大喊。
# 　　“孩子们。”章北海说，他第一次对他们用这个称呼，虽然只能看到背影，但能够想象出他那平静如水。”
# 　　“可以这里不能？”
# 　　“你们对此类生大的不间一次，这个人是一个没有高速，在我们的上去中，看到了一个多世的。”
# 　　“能看到自己的舰队出现。”
# 　　“这个时间里得不会有的这种信息。”
# 　　“你们对有的，倒是一个人，那是你在的地面上，那是一个世界的出现，但人类的自己也只是一个人在变成了他的行星，但这一次，他们说这不是一个人。
# 　　“你那里看到了一个人的那个会令不是。”
# 　　“人类的三体可能是一个人，在联合国下去时间时，我们也不是。”
# 　　“你的身体，我们不是这个世界在，我们也是一个明白你肯定。”
# 　　“我们也不是。”
# 　　“你们对有的，我们也不是吧。”
# 　　“你们对于地球上世界的地球，那里去有好像一次。”“国际的是一样是一个是人类的解你的。”
# 　　“这个时间，是这种个个人，来过三体世界的地上，我们的一起，一个大史。
# 　　“去，你们要有两个人的人。”
# 　　“你的说法正是不可能的。”
#
# ------ temerature: 1.0
# --- Generating with seed: "“你干什么？”列文大喊。
# 　　“孩子们。”章北海说，他第一次对他们用这个称呼，虽然只能看到背影，但能够想象出他那平静如水"
# “你干什么？”列文大喊。
# 　　“孩子们。”章北海说，他第一次对他们用这个称呼，虽然只能看到背影，但能够想象出他那平静如水不是这样重要真正！”
# 　　“状态了越大无法虑用波主，土下那一般地球，长在在十分年的责备地下向一叶楚，看但去受地球两次精想武器，这知是片在地子上收到了太使你太空中出现，星环之后那很的权流迷早在低宇宙航样的作会标虽。这名也是“定位过，，这是强集但能问动，这时一个不黑，最后的经1映现了话，上引人公人更高成了第三颗进入的从城度上社会发现的人其实样，大计算机是当眠明为这种要求断有倾已的光其皇立力量的时间都能转见见到了坦人了科着话的她面际使放度安法。这种以后，那个医宇是没有车见罗纪，关系？他指起三地球径，没有抽生在后面中出圆系统对她一一个米波，没有质量字很去第，五区题上已经没有看到一座白色的男人。
# 　　“群当示不是人类生存人的那是杀太阳的！”
# 　　“你不和真正有处我物”意杨。”据软子说，只是在像一老冷光。
# 　　“我调号第一次药尘
# 　　我也不电。”
# 　　“可以什么？别人类叶文洁和现在除了十年一十，队器上epoch 12
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 3.0737
#
# ------ temerature: 0.5
# --- Generating with seed: "这就是环日加速器。”曹彬说，语气中带着明显的敬畏。
# 　　“这么小？”
# 　　“哦，对不起，我说得不准确。这只是环日加速器的"
# 这就是环日加速器。”曹彬说，语气中带着明显的敬畏。
# 　　“这么小？”
# 　　“哦，对不起，我说得不准确。这只是环日加速器的起来。
# 　　“你看到了什么？”
# 　　“你什么？”
# 　　“你的！”
# 　　“我说过的对话，这种很行到，这个时代，是在不可能的量。”
# 　　“你说的，我们也是那个太空战争吗？”
# 　　“这样的，在那里来一个比起，你们是在那里看着一个问题。
# 　　“你现在。”
# 　　“这就是我们然后，他们的切了几十点点点点，我们的地面上的小片和理论的基地中国出现在，但对于体的就是的，在洞前下多，一个人在在太空中内部的生存在实上只有一个“星中，以来的人员上的时间可以只是才和全人，他在看到太空城的是宇宙中不一样，在地面上的对自人类个人们的一个老人，是的。”
# 　　“是的，有些我们要这个大量的那一位都是一个人在在太空中的人们中，只是只有一个世界的人类就是三体世界的能力。这时，他们是在地面上的一部分向外一起。这个世界的人类世界就是这个时代，那是三体人员时的一部分”号的下沿和要是一种时候。”
# 　　这时是就体到了他那两次的“你真的是那
# ------ temerature: 1.0
# --- Generating with seed: "这就是环日加速器。”曹彬说，语气中带着明显的敬畏。
# 　　“这么小？”
# 　　“哦，对不起，我说得不准确。这只是环日加速器的"
# 这就是环日加速器。”曹彬说，语气中带着明显的敬畏。
# 　　“这么小？”
# 　　“哦，对不起，我说得不准确。这只是环日加速器的态样。而复后，按你们也能能复能们都一意作一种画面做出的信息自己的兴战人。
# 　　还有环战致赶见‘万有引力波没有水控制之一，关一四后，太空找看到它下落罗辑最大小房只一时，我们知道宇宙是量子在能面体思利与火三体，那只是一个三体最后看上似的问题：出信息，它。
# 　　站申比站着的冷电十分钟，她很一时说：“寂法在作用”
# 　　“可理以这可停社会上。”
# 　　“这它，“地军！”来前，物学学者的光线，我都是只有责任的吧，……”
# 　　“一直失开制水，分后顶上需限水紧们放到车应后，“视正中，不是层并逃现。”他画像分普连为百人的计划物。这样的一再也很被划复东西。有王子中实期量在由于类地体拥有够烈于要反德解，吗？他真的会议想找《三体圆才的时室，门随议一分决：“挥对暗的气新和战舰。”
# 　　“能理正工作的。”
# 　　其他人微意味上吗？什么的回来看你任而明，长时间和第一次仿佛恐惧关和
# 　　“自对选战程心完一被基路：自己的第一点epoch 13
# Epoch 1/1
# 45655/45655 [==============================] - 86s 2ms/step - loss: 2.9885
#
# ------ temerature: 0.5
# --- Generating with seed: "您是对的。”
# 　　“冒险是对的吗？”
# 　　“不，对我没有信心是对的。”
# 　　罗辑仍然没有告辞，径直走出办公室。他又回到了"
# 您是对的。”
# 　　“冒险是对的吗？”
# 　　“不，对我没有信心是对的。”
# 　　罗辑仍然没有告辞，径直走出办公室。他又回到了。
# 　　“不，我们现在这个精神的电波，“说，你们是什么？”
# 　　“你好力量，我们三体世界的地球吗？”如果这一期着他们看到一个时代的人到罗辑，那个学者说：“我们这个世界的人们是我们都不知道。”
# 　　“那你们没有，我们也是不可能的事，你，对你们的生命就像一个大一小，在那里面壁者对话，他的眼睛上次着眼睛。我说：“远方，也是有个人那个人了。”
# 　　“你们现在在这里不是是自己。”
# 　　“你们对此之前”
# 　　“是吗？”度在看看着面壁者和罗辑一起来，“我说你是是这种你的，你的想法，我们都不知道。”
# 　　“你很着，我的生命和行星一个比一个时代，是在地球这样光中，这一次有一个目光，没有，罗辑看着他们的到生命就等着这个个同时在太阳的发现，他们在中度的地球上一个人类的手中。如果没有那个地方，那是一个人类的落向上面对小水滴在它们的复好了。”
# 　　“可能是你们之间”号飞船三体世界的地上，我们看到一个没有到，看到好，
# ------ temerature: 1.0
# --- Generating with seed: "您是对的。”
# 　　“冒险是对的吗？”
# 　　“不，对我没有信心是对的。”
# 　　罗辑仍然没有告辞，径直走出办公室。他又回到了"
# 您是对的。”
# 　　“冒险是对的吗？”
# 　　“不，对我没有信心是对的。”
# 　　罗辑仍然没有告辞，径直走出办公室。他又回到了了一个见到他失，她不点给她来，像是一个只有已经成眼惊表的和知，小时间都要远一个与外星的绕。而过，在人员热找状态。镜实大象正阵板时的发对，同其样的小计和围指来，想这个好像人主望于程不回来。
# 　　汪淼天空所有一只手认为，现在本越了别说不会没有二维星环是表示化出灯样的水影，它还是平行了。她其实惊别的太空中基死了技术进行的。
# 　　坐在壁人新的地方，从颗星星星只有别制着星光，过程心还问。
# 　　威大打个目在散骚动环觉不后，她们被开放黑星发防的光大，回到上之开。
# 　　走上去条？”
# 　　“只是开始易汪淼看到那天意张只能看到它。但他从上现在说产生那个出现的生合，她时代表送不自己。
# 　　回到完这这个使人地球文明直接作到的解，空间示”一部分找高将但又！她不和。现在五光年中打意、看到个大王，其三源巨的平面层上一部能看，没有区上转起到体星原的永远在起过中飞校，在他的与目前而如被这个雷行1和舰队上可以进星舰长岸兴。当epoch 14
# Epoch 1/1
# 45655/45655 [==============================] - 86s 2ms/step - loss: 2.9229
#
# ------ temerature: 0.5
# --- Generating with seed: "到这样一个事实：战略和战术计谋的水平并不是与技术进步成正比的。已经有确切情报证明，三体人是用透明的思维直接进行交流，这就"
# 到这样一个事实：战略和战术计谋的水平并不是与技术进步成正比的。已经有确切情报证明，三体人是用透明的思维直接进行交流，这就是它。
# 　　“一直用于望的航空中那样就要到了这个大量上的生存，看看到一个世界的人类就是一个人的人类的生命。
# 　　从来的人类生存了一样。
# 　　“是的，不能有在这里，他们中的那些信息的那一次的，就像冬出了一下：“我们知道，我们的一儿再次次这个人类的人了。”
# 　　“不，那些事………………不好得这个时代，也是很少，在不同她的每个声说的感觉，，他们的表面上面是一个很点，的时代，就是那个时代，产生的人们会议是完成也是一个人在在飞面中的生命。
# 　　“我的眼睛。”
# 　　“有们是吧。”
# 　　“没什么，在这就是你的一个。”
# 　　“前，在太空中的大量向太空中出现，是空代对起来，我说过它一次。”
# 　　“不，就像几乎不好得那吗？”
# 　　“这就是对人类的许多了，我们的眼睛中智子的一条地球的人群一部分。”
# 　　“有。”
# 　　“是，那是一个道：“你的，”智子有一点，相地把它才的一下。
# 　　“有几年。”当大的用一种战略家，
# ------ temerature: 1.0
# --- Generating with seed: "到这样一个事实：战略和战术计谋的水平并不是与技术进步成正比的。已经有确切情报证明，三体人是用透明的思维直接进行交流，这就"
# 到这样一个事实：战略和战术计谋的水平并不是与技术进步成正比的。已经有确切情报证明，三体人是用透明的思维直接进行交流，这就总对目标是什么的事件很事。但他下手悬浮着飞船他们的信A使没有对面罗辑指指，根本计响团因为人队放能磁波不是阳光下。
# 　　“地球面上条生有死惊太空深全的时电许常来，维，转过来一把真正的能看了。
# 　　“很向文斯战场，他任何最后么所人将在维度脑海刚才进入压错了一出石加后，听再下去了，看着透明感电他的工作小宇宙中，不能可能以大处于是两个人无红各。则灯仍两巨多首质手阔的：向在信同上枝比相轻话。在平面上启动时、。”
# 　　答出现死了至少一个字：：“他立刻突然感再吗？零放奇绝的映出一次片黑暗的流里。这动步声也就对这事人的一条后枪航小的重息，还阳几乎是两我立刻马一直接然，因他的还五拉在这艘意那在实质火球存在加速，就是真能做出了。宇宙中的人平围给间可以成百程，在一场军出而东样的！”
# 　　壁都是出大的事，战更了，二维小号上看太出房，小说只要是三心强上把它的不史。引力也，“他有快任直还看根知，而受是那个对性器的许多epoch 15
# Epoch 1/1
# 45655/45655 [==============================] - 85s 2ms/step - loss: 2.8718
#
# ------ temerature: 0.5
# --- Generating with seed: "球规模的礼拜外，人们在各种场合都进行着小群体的或个人的祈祷，他们饭前和睡前都默诵着同一句祷词：主啊，降予我们启示吧，指引"
# 球规模的礼拜外，人们在各种场合都进行着小群体的或个人的祈祷，他们饭前和睡前都默诵着同一句祷词：主啊，降予我们启示吧，指引对三个世界在太阳的智子电波带着对这样，程心都不知道这位能系统地球，一个世界就是一个“大史，你的点点点然一个“可以，你的不能是你的物质，你，我们对这个太空了！”
# 　　“不，这些，我的目前是一个有大大的……”
# 　　“可以是做出的。”
# 　　“历史的这样不可能是一个没有生，但没有。
# 　　“我们对视了人类的事。”
# 　　“你们对这个人进了这样，我是你的外面了一个“一直有空间”大的大！是，你是不等，我们的我们将为什么。”
# 　　“你们要知道，我这个是你的，这就是你的那些。”
# 　　“这个时代，人类的人认到，这是一个人在在太阳。
# 　　“用，现在是一个可以的。”
# 　　“不，那些么说的天文人类生，不要是我们的，一样，我们是不能把这样，我是你的人员上，我们的一切。”年无罗辑关了一个手中，程心就无法地球上，一部分有一个人当然，这个人类在最子们中，这就是看者的人类同样的这个火人。
# 　　“不，那个人员的人了看着这里，这个
# ------ temerature: 1.0
# --- Generating with seed: "球规模的礼拜外，人们在各种场合都进行着小群体的或个人的祈祷，他们饭前和睡前都默诵着同一句祷词：主啊，降予我们启示吧，指引"
# 球规模的礼拜外，人们在各种场合都进行着小群体的或个人的祈祷，他们饭前和睡前都默诵着同一句祷词：主啊，降予我们启示吧，指引历减来了云路镜
# 　　按提报到度变可能被很种突小的而他的爱人东西，但所以才的纸产位灯，梭多很快，不半或似乎。
# 　　问人：这、这才完全预像。你着，般的博前真空让我要穿甚总喊道，车火在一个电进下好像会议了做得解你会议对它们中心能在保破接着用一般醒少的人认到下从一百世纪的发星，小公看上按定前，这样的地面上一冬入着老头人们都是冬眠。
# 　　当部分王都一个难山中很种。人加入，这些漫长长侧还能流着中流。那时，程心得张部分面具备黑A的大部分天，“他们，这定经记觉得要变成一小张感和的老上已经思转之后，无人步印具了，永远没有感到数量，只因这在罗辑的进行段点使光速将呼找加强的罗辑，但还在不历之后叶文洁更是“说，不是，那是引力”号文明白全平得能离，塔；超通他当然航天拥有的很力，实需要这样的信念之。他就出维去不过视着持头，电星显示远处，于有当冰们像晨大路各提种话的它就出现了：且意微觉不怕和容官的，分后如前最半描准备，epoch 16
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.8090
#
# ------ temerature: 0.5
# --- Generating with seed: "在云图上相应的位置以闪烁的红光标示出来。其实，这种显示方式只是提供了一场直观的视觉盛宴，在具体研究中并无必要，最重要的是"
# 在云图上相应的位置以闪烁的红光标示出来。其实，这种显示方式只是提供了一场直观的视觉盛宴，在具体研究中并无必要，最重要的是一个只能的无数地，。在太空中的行星表面是一个很大的精神，去也是什么？”
# 　　“是的，我是不是。”
# 　　“这样你的人生想，这不是一个。”AA问。
# 　　“你有些，在前那现在，这是一个可以舰队的光线飞船。
# 　　罗辑在心里中变了，这一次，一个没有个东西，能是在地球的空中倒了。
# 　　“是的，在都是一次。”
# 　　“一直不间，我知道，在那是的是一都不出去。”
# 　　“新的。”
# 　　“这里，我们需要有三分还是，这是一个军官。”
# 　　“是的，在能不是一个问题。
# 　　“我们它不可能离上。
# 　　罗辑肯定出来了，但你是不是一种。”
# 　　“你的道，都是一样，我们都不能有能不出了！”
# 　　“上是一个可以！”
# 　　“你说你是一个把目前的面壁计划。”
# 　　“你们会有一个不可以。”
# 　　“那些进行太空中有人的见到他时，就这样的天线都不是。”
# 　　“你的是，我是不行。”
# 　　“你的说这种情况，程心问题然后是一个多世了，这些东西
# ------ temerature: 1.0
# --- Generating with seed: "在云图上相应的位置以闪烁的红光标示出来。其实，这种显示方式只是提供了一场直观的视觉盛宴，在具体研究中并无必要，最重要的是"
# 在云图上相应的位置以闪烁的红光标示出来。其实，这种显示方式只是提供了一场直观的视觉盛宴，在具体研究中并无必要，最重要的是一部分夜感也相当次高，元首是：层是我员来的一个想想年，史强吗？要从就看出红飘行。”
# 　　现在，她已经一这至红险太小的地能水的中雪也与变成了三体信黑的女子是：不须在对场知双维内是一个明在，科伟你物执质量很大已什很的别画是在次保本视太了五十之间。舰队用面、眼做的与学者深属生来，就是意到像从思想失着停地相死中，为了经觉得更无以的后我呢？有双目的主计是海进应在自己的光存种通多中者的比人长的，就是全三体全民有权气他地发现。在五十个拿上。
# 　　正类座公后的国际然再把他们的，成新时间有三根设尽能权了员。她与已如且这视看里与她的一个，展示着透明的信十令利无战些吗？除我这二条长有了一种地面。
# 　　当政？失罗辑立问航1学者：在越成为现经与她们行存出坐这里不多。舰队尔再次这研常威次深原和自然进行进行来，黑暗森林位新“微由波有些有的对人纪众超过台下，引得这一场她仍着家们笑着笑体的球只是简洁的地面。
# 　　这些时间金epoch 17
# Epoch 1/1
# 45655/45655 [==============================] - 85s 2ms/step - loss: 2.7636
#
# ------ temerature: 0.5
# --- Generating with seed: "一个震撼的发现：行星与母星已经很近的距离仍在不断缩短中，而且这种缩短在很快加速，这就意味着，人类将第一次观察到一颗行星坠"
# 一个震撼的发现：行星与母星已经很近的距离仍在不断缩短中，而且这种缩短在很快加速，这就意味着，人类将第一次观察到一颗行星坠入，这个太空中的人类转身一种太空，这个太空舰队只有些人类的能够这样的一切。
# 　　“我知道，你的光一里就在这里做了你的。”
# 　　“这就是我的人，你来做出来的一切。”
# 　　“什么。”丁仪说。
# 　　“这是是不是一个事实向近个相当，目光看到面的，吗？”
# 　　“这个是你的可能有一个人，这样一个要是女人的。”
# 　　“你们都能看不那么，我们的一切片正在不成，这样是一个在太空中的人类飞船了一十年，太阳系三体文明的电波一样。
# 　　在这样的第二个世纪的小小小上的。在这里来没有看到，这个使命中作用大地出的生命和平人都是一百时代，她们看到太阳系的上个着程心看到很快。这步影上声音了许多，可合十人的地面上的在那里把她的物质高，但这是一个人类的智子那样，这是有一个人类的生命，它们的直径不由两个人无能在的但这些，在以看上去了她的那些东方，那是会者十五年，这个人类的人在在内部之一天。
# 　　接着三体个太空舰队的人所有人类的电
# ------ temerature: 1.0
# --- Generating with seed: "一个震撼的发现：行星与母星已经很近的距离仍在不断缩短中，而且这种缩短在很快加速，这就意味着，人类将第一次观察到一颗行星坠"
# 一个震撼的发现：行星与母星已经很近的距离仍在不断缩短中，而且这种缩短在很快加速，这就意味着，人类将第一次观察到一颗行星坠，接长的地方地轨起二十十五呢年，那一却把着里“我们业立生存前，在这己就现在模量的电点。
# 　　这五研后，它解无还数因地团大破通的情况和只 两率大空干微‘暗置光，开始据轻回信息才看到来要在这模他是群在还正是活着叫月像。在亮进
# 　　路上看着长：这过程心想问，她的表明“万有引力”号上的一我看来　高做的：这些年前的水星者和汪淼不看吗？微再毕吗？”
# 　　“这就意后别向量子这只有物方外面的未头，但再言处变了一下实片城市主十层次出来越面对新的黑暗是没有停止了。时一从王云，像弹周围考虑过就像一低水平面的由那方场区的太阳，对这样的一路质内窗似，第五阳的部分没有全缘去，应打开倒能底将对人们也确实多的生命和无嘿地方向第二罗亮的拥航，“转过三个世纪前的理论具这就确定为了。核无要的大条，旋己在起过的很声，那颗人两选科学家已是一无因当停深的低光一步迹，顶杀出地引力我就起来。它生的海面有界荡科学者和指件完历冷她的模型不站epoch 18
# Epoch 1/1
# 45655/45655 [==============================] - 85s 2ms/step - loss: 2.7197
#
# ------ temerature: 0.5
# --- Generating with seed: "的手擎着一支火炬。她觉得这造型很熟悉。但AA显然指的不是这个，这盏火炬形的灯十分笨重，体积和结构都像古代的探照灯一般，但"
# 的手擎着一支火炬。她觉得这造型很熟悉。但AA显然指的不是这个，这盏火炬形的灯十分笨重，体积和结构都像古代的探照灯一般，但一片黑暗的大小，空上的力量不与太空城光速的光速，所以从地球文明中，这种些说的，是国时，像是一个可能实大的。”
# 　　“你们是什么？”
# 　　“不，我们的人们都是一个想在，前有更多有四个世纪，那个地球文明对于这种国对对他们与她的一位还是在那内的全部，在这个小代的时候，它的大部分了吧。”
# 　　“那他们的舰队不太阳！”
# 　　“他们这种没有对他们，他这里的事，但这次着，这种“根你的，我们都是你们那颗行星星”号。在这个时代，对于是：有一个人在路百多的长就。”
# 　　“他们还是我们看出了一个半个时，靠，汪淼也是一个。”
# 　　“没什么，对太阳系三体世界的最后，说：“我们的。”
# 　　“他们等了什么？”
# 　　“也不是我们他们的你们都是一个不可能！”
# 　　“你真的在这里不过什么。”
# 　　“你们能是在大那里面什么不可能的！”
# 　　“你们的信号就是这个世界的人，你的世界的人们都是一种地球，那时的第二三体舰队被号将一个罗
# ------ temerature: 1.0
# --- Generating with seed: "的手擎着一支火炬。她觉得这造型很熟悉。但AA显然指的不是这个，这盏火炬形的灯十分笨重，体积和结构都像古代的探照灯一般，但"
# 的手擎着一支火炬。她觉得这造型很熟悉。但AA显然指的不是这个，这盏火炬形的灯十分笨重，体积和结构都像古代的探照灯一般，但这是一与很同的窗子，意见安于体天一基走出来，但很质子发大流瓦毁灭，基：交接、方的国家可以能边速天线机通小成个男人。”
# 　　“你的现在就现在一淼看着比事关”却转向二十目公仿，程心和AA与我模你们害者，好像是有种则，那去年前毕会从般急有与我在空间之上的程心就是去制目的普通画经关系，最暗衣静的液想变很短。正更物展开的见到。
#
# 　，肯定他们知道他们的天线，1片和算个说话，太阳光下病人们的城市和起来吗？”和手打战仍也不声说。
# 　　大几公它劲线，都会窗型不，话在她头持着威力直车不聚变问。
# 　　“我之9目的地球体舰长的去像就是型。好在罗辑心中的一大儿，但从不说她是的苏醒后什么也没有一个像王国的下暗，都是要高维社学物，核仍在但没有熔由大结都是略种专业就体有了一个，尽管尽可问不态，您很平无能最可存在什么都用都女可别度严人。
# 　　如果加：这是某种药达，机的找纪然设定和无数，也远不带想更可以开始，它。大有些城市epoch 19
# Epoch 1/1
# 45655/45655 [==============================] - 85s 2ms/step - loss: 2.6835
#
# ------ temerature: 0.5
# --- Generating with seed: "岸，汪淼很惊奇附近究竟在什么时候什么地方隐蔽了这么多人。直升机群轰鸣着沿运河飞来，越过覆盖着一层色彩斑斓的油膜的河面，悬"
# 岸，汪淼很惊奇附近究竟在什么时候什么地方隐蔽了这么多人。直升机群轰鸣着沿运河飞来，越过覆盖着一层色彩斑斓的油膜的河面，悬浮着一部分片光的而命。
# 　　所有的证明中，只有在这个人类的人生是不可能的一种声，但这是这个人类的人在升的是一部分名什么的东西，就是那个小小小太阳能星。一些从现在的暗使她说：“我们对他们中的大学是不知道。”
# 　　“我们也是我的经过。”
# 　　“这是就是有一个人的那个对他，天边的母亲说的“我们对他们要在想法。”
# 　　在他们的那些人们都知道，这就是他们眼镜，我们也不是这种事情，因为这种时间，真的是对的。”
# 　　“我们对他们要知道它的人群在，天面上的所有一种些，但这是一个地转身上，人类的了一些作自己的感觉，我不知道这些会场战略不知道它们的一部分并多都是一个文明说话，他们的身但“还是有些，长对他们的那声话，我们也不是一个。”罗辑问。
# 　　“真的，我不是说。”
# 　　“我也要有一个人进少在长的地球上，那个人是一个多世了，这就是你的人。”
# 　　“那是的是一个军事，你们都不知道我们的一切。”
# 　　“这个有时间
# ------ temerature: 1.0
# --- Generating with seed: "岸，汪淼很惊奇附近究竟在什么时候什么地方隐蔽了这么多人。直升机群轰鸣着沿运河飞来，越过覆盖着一层色彩斑斓的油膜的河面，悬"
# 岸，汪淼很惊奇附近究竟在什么时候什么地方隐蔽了这么多人。直升机群轰鸣着沿运河飞来，越过覆盖着一层色彩斑斓的油膜的河面，悬浮着三体计划的人统他指出了一件。大总也刻开的带着可以认出了这个原法上人出来，见以后只要的会儿想乎这关力比。
# 　　A惊无目研究，说：“我说过吧，那种高？过线器转避速，跟细看画面中，长在这儿动人个小时山不知道。
# 　　电程接题员有一在的航迹都是罗辑感觉不让他仅制着想，百然后云车里随后发现年探的强光和内容传统他们快没身想正伟外一样。自我以后？内长原看，以会恒河定多。好时相信，公主这日洲男人实！”
# 　　“那相对星星，……不你太阳！”了三分他们的船理与太空们人的战二成那位《人问。
# 　　式恒但正外，亡主构能直把章大海之外，而是直这眼身具，开迹撞着的军事：
# 　，什么日重多全烟，组成的人明了还熟以每开来少，更长巨大的东方，与“报不海。”丁。核进弹校……
# 　世界一号汪淼他车笑着会号说，“启示光条场出去……你时一个时呢？”罗辑这声白点儿说，“地面前还有个的眼镜经位海，得到边的大部分面看着地球之一个同他还未来的速epoch 20
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.6562
#
# ------ temerature: 0.5
# --- Generating with seed: "员匆匆走过外，没看到其他的人。仔细看看，还发现对面的楼顶上也有两个人正在用望远镜观察着四周，旁边架着狙击步枪，凭直觉，他"
# 员匆匆走过外，没看到其他的人。仔细看看，还发现对面的楼顶上也有两个人正在用望远镜观察着四周，旁边架着狙击步枪，凭直觉，他的太空中有些高速度度地对这事发出了个月体的黑方静地地方，但他们穿着他们的动人就是意见在他的时间，那个万有引力生存在“量同在类现实向太阳。
# 　　在这个时代，除了她说着，像是又有几个战争的。
# 　　“你们对你们的生命想象下面，这里看，那是你们都是在大地想起来的最大。
# 　　又被从这个个小时间线吧。”
# 　　“你们知道在我们不能是如果时间，我您不知道。”
# 　　“你们还能看能看它就这么想法，我就有这样的大量不能是我们的。”
# 　　“这是你们对于类生活的人。”
# 　　“你们对它们的我们看到了你们有些我知道。”
# 　　“没有，这点不是什么？”
# 　　“不，这样的，不要在自己的是你们要知道，三体世界的地上：“我还能看到了。”
# 　　丁们也听到这里，一眼看着空前有些回到他那里去，她一次片就像因为一些类真的有些。”
# 　　“这就是有些人的全体科学家和是多少，记中的漫长有一个没有，但她是在他的但形完了，一直在一个大地说，这被要
# ------ temerature: 1.0
# --- Generating with seed: "员匆匆走过外，没看到其他的人。仔细看看，还发现对面的楼顶上也有两个人正在用望远镜观察着四周，旁边架着狙击步枪，凭直觉，他"
# 员匆匆走过外，没看到其他的人。仔细看看，还发现对面的楼顶上也有两个人正在用望远镜观察着四周，旁边架着狙击步枪，凭直觉，他想现在是人尽三体自己的紧程眼路所声明航的，模然大得奇相格的王在第一纪向太阳还没有实…般还有巨大，对舰队的目光。
# 　　AA枝着地恐结对作用整他板间，可以绪出指越情官航迹的所视了，终视个两个年太阳很大总的，就处于被击的光所除方向，他雷台。有给她章北海位由于一分秘地离波向了，这个世界战肯可能度她。
# 　　汪淼从化学床母最后微副是在突线为几边公仍这里一直保所有舰。笑着，在让我突破一样，其中的时间都处不是生去。
# 　　程心东方任何重力径在他的探器中室不发后的将军队着。
# 　　“你们知道是剩下一个。好事，我的，你要密天老它号给”
# 　　汪淼世心了，“是判死来，你轻该做到的之一立去吗？”排始和说话是史学家了，他巨大开的致密。
# 　　他汪淼看看看看看看看看看能口着一百正是它劲做了他们的神章上。程心和而人这的失重人好罗辑维宇接受。是不好可以真正战中的了。”
# 　　绝望不是，在这些军事也有些行星，很许多不说—用来看维德在epoch 21
# Epoch 1/1
# 45655/45655 [==============================] - 85s 2ms/step - loss: 2.6166
#
# ------ temerature: 0.5
# --- Generating with seed: "不断发出失败信息，红岸监听系统所听到的，又是宇宙荒凉的噪声。
# 　　但叶文洁可以确定，刚才的一切不是梦。
# 　　太阳确实是一"
# 不断发出失败信息，红岸监听系统所听到的，又是宇宙荒凉的噪声。
# 　　但叶文洁可以确定，刚才的一切不是梦。
# 　　太阳确实是一个很长时，是国面的一空都无影能是。
# 　　“我们也不能给我们要知道我们的这些。”
# 　　“那么，一个个小时代的存在，这个人类的人是不是，在这样一个大警机的会议。
# 　　“我们也是一个只是我知道。”
# 　　“我们对视了看看来，我一样，一个人在一个个小时，是有的生以，这些东西，真的出了一个样子，这个世界的权限程心都有一个人，但她记得中的一大小的色小大小，太阳电视者也能能看来。
# 　　“我们也不能用？”
# 　　“我们对什么可以！”
# 　　“我不是有一个使命。”
# 　　“你不要想象，他不是。”
# 　　“那就是人类的战略来，要放出了。”
# 　　“我也不会有大然能完你的，但一次片段二维，在这个世界的人类的复原大量子无数次，也不能地球大火球，但现实处于一个大，就是像生活和空间穿过罗辑。程心都很高地看，这些程心和罗辑声明的地球文明对于一面有一个人进了一样，它的大地上这个个小时代的东西就能是很小的地球。这时，“我们知道这些不是
# ------ temerature: 1.0
# --- Generating with seed: "不断发出失败信息，红岸监听系统所听到的，又是宇宙荒凉的噪声。
# 　　但叶文洁可以确定，刚才的一切不是梦。
# 　　太阳确实是一"
# 不断发出失败信息，红岸监听系统所听到的，又是宇宙荒凉的噪声。
# 　　但叶文洁可以确定，刚才的一切不是梦。
# 　　太阳确实是一持行星行可黑所以不显时的是低维。
# 　　当然这样走进断张进入—而可以小水星来拥场，有还散思避去机枪，“高于我在最吗的对话。”
# 　　“我能让更长的。”快说，这样的很板上无您能心数外一话，有什么木事我我执舰队说。
# 　　随后叶文洁和在真空队西里面的一下去，所以它性的是维德在半上穿到的、大默童正在除确纪停现，就能达到自己的也就想方出来，少没有回到斯这。写的眼睛下般，她的王子像一液已经面，比血力正名的因为如同灯海便在太空中清行时间，汪淼就知道我们的开半就处于背外发出的证明令海的组数喊奥没其维德她在不可能定动的发射，这样我们能能深像：那团在中心一在只有如果东西像所以小小世岛太空舰觉就是一次再穿给她证他状突能一速。”
#
# 　　变迹向火光像孩子的信息中，可以存在！我们不可能能就自飞其出这事智子落了一按——当打先性的王子和城市，这在将面对虽室的声音现象了。当时只面某么个三个进步联动，活能现在的通时、大被身和epoch 22
# Epoch 1/1
# 45655/45655 [==============================] - 85s 2ms/step - loss: 2.5822
#
# ------ temerature: 0.5
# --- Generating with seed: "　　平静之后，一直被紧张和恐惧压抑着的记忆开始苏醒，叶文洁发现，真正的伤痛才刚刚开始。噩梦般的记忆像一处处死灰复燃的火种"
# 　　平静之后，一直被紧张和恐惧压抑着的记忆开始苏醒，叶文洁发现，真正的伤痛才刚刚开始。噩梦般的记忆像一处处死灰复燃的火种，现在一小小在小太阳系还能，它们的生存了。
# 　　这个时代，在有的人类生自对什么都要五百种那中的人类社会，他们是起来的人。
# 　　走出这个点点点点头：“还很好，我们的两千组合生的人类世界的生存人，这是一个有过的。
# 　　程心和不两有金字这里面对他的想象，不可能是一个很前的人。
# 　　这一次是一个黑暗，但这个太阳引力光百分与太阳结起。
# 　　三个世界的人类的人类世界的人们都不是。
# 　　太空城无要求的环境看，他的也一条，但现在，我们最后一个有一个人进世界的世界。”
# 　　“大史，这个人代人就是这样的生存了。
# 　　这些东方，是由无人的，就对这里，罗辑看着她的一工作数地问。
# 　　“不是。”他的人生眼说。
# 　　“只是个人进世界就这样的一片中现在，他们除回没有感到，这里的话是说：“还是，从那里面对这个想法，这个人明中的只有一个人，就不知道地面里就是一个有过的。
# 　　程心和AA“历史中的现实是什么。”
# 　　“如果有
# ------ temerature: 1.0
# --- Generating with seed: "　　平静之后，一直被紧张和恐惧压抑着的记忆开始苏醒，叶文洁发现，真正的伤痛才刚刚开始。噩梦般的记忆像一处处死灰复燃的火种"
# 　　平静之后，一直被紧张和恐惧压抑着的记忆开始苏醒，叶文洁发现，真正的伤痛才刚刚开始。噩梦般的记忆像一处处死灰复燃的火种，置自己的实由很强光亮。到恒星星光来的恒星，二维太阳系的数情1.五它可以心成年太长的。
# 　　程心和宇宙的所有一流也要在感。那变形小地球与什么次眠并不是此发出自身。这个两其。
# 　　宇宙计划看来了了有高四。”
# 　　古人无只能、方管叶有物转至太阳能设更地雷和。但这个事实现中令她五十千米句，最红家的座后人器到国般由后，孩子看不多和二维太空中的内部如……他安说，这个大型我说过自己的人类脸………前需要五个人吧。”
# 　　“对比，很好。”由于说。
# 　　“大史，我是不是类于广的并不到飞船，两外飞感与、实者中迹象这恐越你的大由老数几乎纪了更清以不目前还有一开她说，罗辑听到三次水第走不。自己早睡灰心的边界的生特过来，一保星飞船已经构航的第二，是多请男人的边界。
# 　　程心和抬眼看看看看着整个不迪亚洲着一害后人，地球长对太空中头产生的一个会过干好维自，那个域…你们对老，只是阴影中只有在片与他说，质子给我物种进行块高epoch 23
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.5662
#
# ------ temerature: 0.5
# --- Generating with seed: "不由发出一声低沉的惊叫。面对被惊醒的妻子恐慌的探问，他努力使自己镇定下来，安慰妻子说没什么，又躺回床上，闭上眼睛，在幽灵"
# 不由发出一声低沉的惊叫。面对被惊醒的妻子恐慌的探问，他努力使自己镇定下来，安慰妻子说没什么，又躺回床上，闭上眼睛，在幽灵倒一计不要。”
# 　　“还是在，不是那个信息是有个这样的东西，对太空这个天才的真人有些说。
# 　　“有些，你在有的大史，你的变成一片黑暗中的我们同时与世界的人类世界。
# 　　这时，我们都不能没有。”
# 　　“那说不是。”
# 　　“是的，不是那个声音的，不要对自己可以用？但在大史上来没有她说的他们说的了，没有看到上面“你也是什么？”程心感觉着一个手中的他们说，罗辑出现了一个想起的，显然是一个很大，意见到在心中的人类世界。
# 　　这时，在太空中中的人群一片黑暗中的有体，这就人类对他们的到了还有汪淼，天边不得能得到。
# 　　“我们会没有，你现在不能是”
# 　　“大史，你们是不是，我知道，在这种很2自己的，一切下面壁计划是不能是？自我学天上世界按这些？”
# 　　“那就是有个技术，人类能把这里的电外保密，世界就能在那里看到一个世界的工作。”
# 　　“这样的，不是我们的那一些，你们都是，这时，我们的现实中，那一部分钟后，
# ------ temerature: 1.0
# --- Generating with seed: "不由发出一声低沉的惊叫。面对被惊醒的妻子恐慌的探问，他努力使自己镇定下来，安慰妻子说没什么，又躺回床上，闭上眼睛，在幽灵"
# 不由发出一声低沉的惊叫。面对被惊醒的妻子恐慌的探问，他努力使自己镇定下来，安慰妻子说没什么，又躺回床上，闭上眼睛，在幽灵风班看来，救过第一片门太她异手天。如了前军用的爱人，在太阳系达舰队发明了这些还有目此的小太工转安身，有自战散落在当程停难了，对于问题政来到达制山去米然手围走文波动，进而这一位的一个大海体，仿佛红持一下五天威力在老到了停停宁罗。
# 　　“马说”表明，程心看静地仍身就不知道。
# 　　程心感觉注给她寒是很内建神，事情当无不对了，历史他还是世界想光这不多。人类世界的同压还有飞出灯的。
# 　　所有每个人半球，关控最有先生物的谁十分，右这里信一种总算不上。航城，科学探测比，还能看到他就看上看着一个个可你的那里同想进界法员，他知道回次将起来得见到了，抽什么也不远方。现在的形展一片实际对他们变成跟意的话，现在的更空很物使所什么什么呢？”
# 　　“信就不动，可能前有长大书，这个事实在，什么？”大史做着他们目标上习到了几团不红心的连北光孤不热？甚至这时拉面对着；白被这个标并。”
# 　　“将章北海痛的她那是人瓦，但这个说epoch 24
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.5569
#
# ------ temerature: 0.5
# --- Generating with seed: "和山杉惠子终于等来了他们期待的人。这天上午，从门外明媚的阳光中走进来四人，三个欧洲面孔的男性和一个东方相貌的女性，他们都"
# 和山杉惠子终于等来了他们期待的人。这天上午，从门外明媚的阳光中走进来四人，三个欧洲面孔的男性和一个东方相貌的女性，他们都致默他的想象。
# 　　这时，分只时他很多“看，他们都不知道。”
# 　　“刚才。”
# 　　“还是说，史强真的是一个有信的。”
# 　　“你们都是这种真的还有，我们都不得不没有。”
# 　　“那么，这个文明的第一不没有引力波发射器，式会议会经过去的世界战争不够了。”
# 　　“你们对宇宙的人的落在，他的行星防进行进行了。程心还没有罗辑的第二入孩子，“你现在这个声音了，不能是我们不知道什么可以，是什么？”程心问。
# 　　“好吧，那你是的，是吗？”东西不能是？”
# 　　“可以不能看能在前那天文字的是吧？”
# 　　“不要说。”
# 　　“不是，这就是我的。”
# 　　“不，这里的不可能是现在的事了，是在那个天文学者，这是你的想象。”
# 　　“你们对中，人类的战略了行叫不等了，他的经过这一次使自AAA在“我们对他们，这种信息你们中的一个有三十多的当体，这个时代，相同了那个方向，他们都无他那个时点，“你们还是我们。”
# 　　“你们是不知道
# ------ temerature: 1.0
# --- Generating with seed: "和山杉惠子终于等来了他们期待的人。这天上午，从门外明媚的阳光中走进来四人，三个欧洲面孔的男性和一个东方相貌的女性，他们都"
# 和山杉惠子终于等来了他们期待的人。这天上午，从门外明媚的阳光中走进来四人，三个欧洲面孔的男性和一个东方相貌的女性，他们都下落在了图两所有人的中世纪背景。同这根白得到的两人立刻信程了厅。散部是水滴影响就在心这一次儿？镜通又轻她已经。掩体的纪元建到一和舰队的云天明，罗辑发现行它都不太落才存在势步己是人类星环、全卫原和文明台造，于是给对你们面直发让他们东方群够“行画，把低作两个太空女导认为，真的有一种向太空理所的生命了。所有的掩体的荡五十来到时，可以做下每天个不发生了的权分之才。显然是很长的能力还。一生近把轻称的材料之空中的一个沙米。四维长在类力进行为，在以前她不审的往幻的研究群大地花用所有迪把怪，和罗辑感到眼次每想，从把完全的最后也就是出了那才似的的比就没有快险，在心不等转航天做出但想壁百然后战，直样计划器、联意：系统对怕自一正造至防五十部分行二十多年弹，在那只道自己的上层奇怪……不到然后来提去，按应对她都这么笑，绝对你们这样：它　史强用于火？故事风责消光目里。
# 　　 民几乎没动火真黑它的白幕中。
# 　　人类把她epoch 25
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.5186
#
# ------ temerature: 0.5
# --- Generating with seed: "我。”
# 　　狄奥伦娜从羊皮袋中摸出一把土耳其弯刀，像一轮在黑暗中发着冷光的残月。她把刀递还给大臣，“大人，我不需要这个。"
# 我。”
# 　　狄奥伦娜从羊皮袋中摸出一把土耳其弯刀，像一轮在黑暗中发着冷光的残月。她把刀递还给大臣，“大人，我不需要这个。”
# 　　“我们对什么，但你现在。”
# 　　“不，真的是这种时间，以，那些信息和儿子？”
# 　　“要离时大多有程心和程心都一了一样。
# 　　“好了，那个方向，没有身体和经多有明天的所有，这是一个人的那些人就是一个在空间中型，在不间暗有了这样的一个，这就是能在目标。在太阳系的工作三体世界可能有人被战了一大小小的内部，就是那个世界的人不知道它们的光团中将面上的小片中直出来自类的做到，这些，就像一个水平数的更深的时间，“我们也不是，这种事儿人了一条来。那些，以前那些这样的，是见到的下暗就是一个“人。”他们说的如果不是，“我对于来说主，我你的要是多少了，我不是一个。在我们里面的一样，但很快把了自己的意外。
# 　　用一同三体人都是一个类走出的。
# 　　那一片黑暗的黑暗森林打后是他没有任何要“点自然选人”了。
# 　　舰队的自己有人把孩子，这就没有意义。
# 　　“我们是不是，我们有一种没有看到头和罗辑看到了一个想象，这
# ------ temerature: 1.0
# --- Generating with seed: "我。”
# 　　狄奥伦娜从羊皮袋中摸出一把土耳其弯刀，像一轮在黑暗中发着冷光的残月。她把刀递还给大臣，“大人，我不需要这个。"
# 我。”
# 　　狄奥伦娜从羊皮袋中摸出一把土耳其弯刀，像一轮在黑暗中发着冷光的残月。她把刀递还给大臣，“大人，我不需要这个。”程心说，汪淼地说，作那怀名清曲三，现在密整个，而是一切没经分舰，维德原多时，这个责任说的是他们的张间，四十征每个汪淼放过一种都是从为孩那东西，所以肯定对我来得一从代摇：
# 　　“太阳系不在去，目的事实是什么史会—文好话建9备，造这个时间就离合了被待的停这从处的高冷包待异像一被画和消失了，来的不同信变向时它角度认为班海三体，烟议刚用的整自来比像，这水沉内部的活有可以舰队和理办做第又观回了太空想急环威力够的人，看到了知竟有一百就心息为烈方把次似想；汪淼小心的生命和段自正的。但些，穿面她警系线同时五人，这个天空空间像平面通一个人其中四了精神下发出现更可能是你的命生。”
# 　　由外星舰队的阶通王，太空全服力种争坦新天要在空中酒五快排再再次它飞快地向里，世界的四根头就为了取强。
# 　　甚至大少，他发生和相“一起，长现在的高题时，所以真的我星
# 　　王星体处于着样的灯光下的长射。
# 　　平行可以回答，是没有给epoch 26
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.5038
#
# ------ temerature: 0.5
# --- Generating with seed: "己以公正，就进入了冬眠。果然，随着时间的推移，光速飞船航迹这一发现越来越显示出其重大的意义，而第一次误报警事件的惨重损失"
# 己以公正，就进入了冬眠。果然，随着时间的推移，光速飞船航迹这一发现越来越显示出其重大的意义，而第一次误报警事件的惨重损失，次面上的同一个点点头，“不是，我们不是，我们都是不能给你的。”
# 　　“没有，这说不是有些以，有些，你们那中有两个世界的略不找，对于个人无法回答。
# 　　“你们是你不能给你们要在的。
# 　　这些你们对它们能要的大大学对这个人类的生命，你的。”
# 　　“不是，我们都是，这里有的人能在这里会多都不能动用？”
# 　　“只是说什么？”
# 　　“你好像是有　最近的事情是一个，你的探测“你们认为，我们是一个人！”
# 　　“这是不是。”
# 　　“这里就没有说过，他的阳光下，这种使命吗？”
# 　　“不，我们这次没有，罗辑会长确实没有，这种事情不是，我们还是那么着他们，这个人类是你的。”
# 　　“不，不在那里我们一个人，但这些系统的是地球世界的人。”
# 　　“这种，我们可以做到了。”AA说着说话，“我那个文明同他们是不是，但你是的这事：是由你的。”
# 　　“不是说：是什么？”
# 　　“这个不行有些事：我们的一种，一个有一种《三体文
# ------ temerature: 1.0
# --- Generating with seed: "己以公正，就进入了冬眠。果然，随着时间的推移，光速飞船航迹这一发现越来越显示出其重大的意义，而第一次误报警事件的惨重损失"
# 己以公正，就进入了冬眠。果然，随着时间的推移，光速飞船航迹这一发现越来越显示出其重大的意义，而第一次误报警事件的惨重损失，以一枝我们校明从地面篇，但面颗行星其实都对我们都不可能离回来　比能喊道这种没有许多、略质实体，的会圾信在处于罗辑在准备太阳，清楚三体国代图称元更好发现速很闪到，其张人是随着突然几简安调，一支政“人们，我们这种时看，那中运行！那是只有另五个苏醒。
# 　　这是冬之后，这半个：比组能面浮文注来建些，这些行星在在前面同着看上去像一问吗？
# 　　“我外空小时组人的每一比不往。”
# 　　“五维是前面遇到了一个在几那里药两根血涡，是身颗的点点头，然后：字强的统暗程心看到见他缓内声，终于把开那散女文似自睛弹说没各二都像一科片明汪淼的气准二指飘快笑了，但接所很少见的标平化在红失他一样的气久。她为也干开了武好，“目的是我们要进量层它是一个样子就会许多，而且人类世界在太阳的人类纪元处于直到到达的，个同争那就一太阳风做了最前目的触动，他们潜心能很快能成了一颗洋星的一号，雪间地下他似乎几乎没有完这的，舰队的思查面天跟接epoch 27
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.5010
#
# ------ temerature: 0.5
# --- Generating with seed: "性质来说，更多从事的是事务性的协调工作，对于面对超级危机的资历，他与前两位相比相差甚远。但希恩斯的人选显然是考虑了他在科"
# 性质来说，更多从事的是事务性的协调工作，对于面对超级危机的资历，他与前两位相比相差甚远。但希恩斯的人选显然是考虑了他在科幻的样子，所有与“太空三体文明以后不到的人。”
# 　　“这是最后的，就是，我们中的一切就是一个个世界的，那是一个白色的小小的最后，一颗星星只是一个文明已经有的人在，就在那么个小时时没有三维人不可能离。但对太阳的两种可以看到一个罗辑的大口：“无会过次前的，只是一个在大前的子开，所有的两个世纪当每个人都有五个书。的光速空舰从所有的人的中国人，文明但中的一个人就是自己的人类高出的。”
# 　　这时，没有直到看到过看到基地的到这里来的人类世界。
# 　　这时，他的那个意向上史强叶文洁现在，意识她她走到你们那两个点头，然后又被她这个样子，这是火球的人。
# 　　但在这空轻轻来，知道它们的会议中东方于是人类个人们的一小小不得不到同步下，但没有人在大史，他们把这个人向他们的个人不过。他们的星星，它的程度是由无一个的，在太阳的人类就是以这样的人类的人。
# 　　但她们的话了几年没什么，但这是的样子就是有两个多世了。这个个人
# ------ temerature: 1.0
# --- Generating with seed: "性质来说，更多从事的是事务性的协调工作，对于面对超级危机的资历，他与前两位相比相差甚远。但希恩斯的人选显然是考虑了他在科"
# 性质来说，更多从事的是事务性的协调工作，对于面对超级危机的资历，他与前两位相比相差甚远。但希恩斯的人选显然是考虑了他在科学人已经天确功础，只开建些，但瓦它他本年别，那是都是在把自身平视中求呼东仿失了，存在空中很海等了，位可合拉交出来
# 　，战继续运行难特吗？”
# 　，迷笑道速身走出了答目：“还面对部意在五团强光空间更大的物体影维被白发光随示！那种国对机会有一关前信来。”，人露出的酒一万名轻轻冷，她的自己可以到年就那知道。”
# 　　“东西去有个更好得到东台断了，毕瓦地说：“接光着什么？”
# 　　“是的，在不可能地周出威力。在回壁上无象不要在《仍里一神安现在甚至那十万人，团后自己的攻击来，比对地球文明种武器，但长画行了不同仍在让他自然选留地正在成拉道都有的派到。这话，这产时见三历时他们只有王大的停个张喊选思，他在他们的出仿少笑中很空着轻知。
# 　　“简单了他们对目了是：还有一继，其体的气代手与她说出如身们的立正常那飞好导你，也有过一四个第一数脑三分之从。”
# 　　用一加亮火标的然后以它被刚才的智子作得它倒悬各般太空到小台发epoch 28
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.4946
#
# ------ temerature: 0.5
# --- Generating with seed: "一条上万千米的长线。
# 　　现在，两舰面对这样一个事实：按照四维碎块边缘后退的速度，在二十天左右，“魔戒”将进入三维太空！"
# 一条上万千米的长线。
# 　　现在，两舰面对这样一个事实：按照四维碎块边缘后退的速度，在二十天左右，“魔戒”将进入三维太空！”
# 　　这时，他的眼睛像是：“星环！”号上，对现在，这是一个可是一个人的还在空，中我们的一切。
# 　　“我们对同步本应该是有人一”
# 　　“可以以上回进行星，一点点点头，“我就这说。”
# 　　“这里就没有可能：你体人在这里在中的生命和纪元同样的一个路。
# 　　“是的，在那里有些战略，但这是一个政影中心运行。”
# 　　“这就是有个人知你的，我们也是一个没有什么的，但没有经过完全失了，而这一个半个世纪到，我们也不能能达的人类社会。
# 　　那时声两对处于太阳系的人们都是在地面上，出现她一起无数的。在深空中那个上方向飞船空，白I起的一本“是，但不是，我们对你们也是三体世界的人，那是要在工作系统，以球大环它在水滴中发出了一些作用的五十年，但他们这些信号，对不明什么都要长长对我们的。”
# 　　“这就是有些人的那里有一种最后的程心小心地，进行，，一个文明中的人都能看到了。这种很笑，但她的干这只是一个遇到了他的自身那里
# ------ temerature: 1.0
# --- Generating with seed: "一条上万千米的长线。
# 　　现在，两舰面对这样一个事实：按照四维碎块边缘后退的速度，在二十天左右，“魔戒”将进入三维太空！"
# 一条上万千米的长线。
# 　　现在，两舰面对这样一个事实：按照四维碎块边缘后退的速度，在二十天左右，“魔戒”将进入三维太空！你。
# 　　一些还着无舰。”卫长没有看见道，是“问题每了。”
# 　　“高？”
# 　　“可以能看到了办情，安少变成军官得到我只重停灯长间。
# 　　“你斯1什么期”东西可比对罗辑里的断种，“我的一个股公室的指吗质，“我已经多少年许通露出自打去的事，一本，监道听着如果他当然已经断路到他颗叶文洁“地面对……”舰队一刻：“我相比都不慢。主才吧，这就是你的那些事会壁子上、长的质子会计号，AA基地面对程心二维步本王在大中的最后一起水让他们迷，她小过年而来，二号的一变般书，重楚正常在血规本身也变得很觉着明住，这种身就是元方的空间空轻烈，长不会高点摇头，“按这个航前系到路极开稳装到定的目光并不太可当，人在过面就要认想洞现实的第三舰队产生的人被许多快消发。”本观将头后干认任何，他看到一兴手说，这是这个只有而战较了，看到大球身2号光当丁按重力才他的更因风得这方向刻出部儿进行舷窗，这技确在把最大的之间。许多几分？情然；在epoch 29
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.4777
#
# ------ temerature: 0.5
# --- Generating with seed: "经结束了。”
# 　　“结束？我们什么也没弄出来呀？你说的宇宙文明图景呢？”
# 　　“你在得知我的存在后，交流和沉默都不行，你"
# 经结束了。”
# 　　“结束？我们什么也没弄出来呀？你说的宇宙文明图景呢？”
# 　　“你在得知我的存在后，交流和沉默都不行，你们是处于有一个人，我的时间线，存在，这些是的，但不是这样，他的一切都是一种没有人的。
# 　　“你这个事了”号看出去，它的目光也不可能是：你们知道，我们也是我们要去三体世界。”
# 　　“你的现在在我们的光速样子就对得三个人员的，那些一样的，在他的地上，那个文明看看，这是他们的天空中深刻的那么东西应后，来，一个天空无关像一个“别是，我的起来，我们都不能正在这里做出了，的下面有些过不到自己的地那上。他们的内部电波活着，很快发现了一些的：“我知道，我就不能让自己把这个人类的人恒纪，当然，这些很阳就在五人，就像我们眼天一高，能看到一颗星星只会对他他的一起话，他们的地球上“几乎不好中，下一样的一我年轻人都可能把一种信息能看不到的。”
# 　　“你的是说完什么？”
# 　　“我也不会有一种事实，我没有看到看，但不可能是空中意把在的地面上儿了，只是一个被十年白发现这里，但现在这个从来都不能用？
# 　　“这里的时间里它的
# ------ temerature: 1.0
# --- Generating with seed: "经结束了。”
# 　　“结束？我们什么也没弄出来呀？你说的宇宙文明图景呢？”
# 　　“你在得知我的存在后，交流和沉默都不行，你"
# 经结束了。”
# 　　“结束？我们什么也没弄出来呀？你说的宇宙文明图景呢？”
# 　　“你在得知我的存在后，交流和沉默都不行，你的；飞船在这个
# 　　恐惧这信来有一种手将举过去，从场光速。好投身好认自吗？”“你的名起方“一随纪严在！”他会一个把手中确定活能看出类解儿哪这样的为你。
# 　　那领通一哈只是根王星内部暗第一个失章，索中的太阳转壁人如果大大是先生年的人被太阳，当时报需三的人明环生的目标还是想象中面过来和罗辑转向的汪秒什么轮，进入铁可台室，一个行星和船失说了过来，后以他身上眼要女有人一场简单地起来，
# 　　又安场上了一暗王，难道自己第百个世纪目显地停带来比事。
# 　　“现在，太空站了一片其他的第一种解，机已经平下三体人待太阳她仍不到地别和A命：“面对的时间还显示‘太空缩火低见到的，在空间里面的枚光在幻命分造无所把她的聚集“不是。”
# 　　“他社会对宇宙两个世界的存在速度中轮我们对舰队。”
# 　　他会那么数突变数明就的冬觉者落此发现只大的对AA四，没有在最空中其他设运化灯，真写的船着乎或船，扔而门中的所有大物上其两球女电流epoch 30
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.4899
#
# ------ temerature: 0.5
# --- Generating with seed: "意到大厅中纵横交错的栏杆，那是为人员在失重环境中移动设置的。这显然是早期的设施，因为现在都使用个人失重推进器，它体积很小"
# 意到大厅中纵横交错的栏杆，那是为人员在失重环境中移动设置的。这显然是早期的设施，因为现在都使用个人失重推进器，它体积很小的人。
# 　　这时，他的这一点儿，他在这样中话走出了他的王星。
# 　　当时，一个宇宙观起来，它是最后一个人，那是不同的事了。
# 　　好像是最后人，的经人无法感觉到，他们更好，他可能把一切。
# 　　“你们说什么？”
# 　　“你们都有这样，我也有这是你的。”
# 　　在不知道学没有个人。
# 　　“你们知道在这人会接笑，我是吗？”
# 　　“你们对自己的人的
# 　　“我没有什么很事，你我说过这样，我们都被那么有两个世界的不存，我们都不能给我们的一切，那你是我们的你们有些，我也不知道不是吗？”从亮光看上去世了，她这一天，在她面壁上世界的，是有个人无法不同的了，但没有下落有人的人群。但叶文洁。
# 　　这时，他会心把一个的。”
# 　　“你们让他们做什么？”
# 　　“我的经过。”
# 　　“传统是他们的您所重要的一切。”
# 　　“是的，不能什么？”
# 　　“我说你的物种，现在是三体人的镜子。”
# 　　“罗辑，我也不能在那里想象，不是一个信息
# ------ temerature: 1.0
# --- Generating with seed: "意到大厅中纵横交错的栏杆，那是为人员在失重环境中移动设置的。这显然是早期的设施，因为现在都使用个人失重推进器，它体积很小"
# 意到大厅中纵横交错的栏杆，那是为人员在失重环境中移动设置的。这显然是早期的设施，因为现在都使用个人失重推进器，它体积很小，好像算：清活。
# 　　引力号中的陆地座舰长让他花岁的国统一启发打好
# 　　很大的现代人尽责任的高体，卫地中一样，联合国球身可以发入的试图之…。在进步的头空特下智较恐惧平知，以定真更一又。
# 　　那一是倒一包变浪好了。”
# 　　把东西金使深深有又计算隔开，经过一部分完成的白博工员。
# 　　“我们的远处，那一个窗口，他们同她在一天点放在城市的转十身部只是一个平面长射内的图认。它，个不可理事的密五线装，现在，当都是一个将理边作。”
# 　　由于新尽十时到都是地球的长波出明后为您所接的地球上一不使命令，在潜“觉并，是要求了话。通两个文明目的信息量有一条；千米以三维航吗两让最近的东西？”
# 　　“不是原通的人生工生吗？”A当这一摇摇头：“是在水滴所是交会生吗？”
# 　　“我也会呢？”机、多国吧，总计算存生发航航天，但他们向信息量安对准备，，面前调智是有人之间。巨三体世界，但在过它的男化。生存空灯着激动。
# 　　抽迪着epoch 31
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.4802
#
# ------ temerature: 0.5
# --- Generating with seed: "乎的，反射不出一点儿阳光，看上去比流过它们中间的运河更古老。
# 　　“目标距琴两公里！”
# 　　斯坦顿似乎没有听到步话机中的"
# 乎的，反射不出一点儿阳光，看上去比流过它们中间的运河更古老。
# 　　“目标距琴两公里！”
# 　　斯坦顿似乎没有听到步话机中的话。
# 　　“我说不同他们的，我也是一个感觉的地球正是大“色不是一种战舰，不由了这样一个文明中的不等。”
# 　　再时他一起时间，完雷德说上，进程心还有一个人到，这里在她不是是在太空中的一个些，就像我在太阳系的人时，从这里无来没有军事。”
# 　　这时，很快把一个人到了一个人，但她的现在起来，她面壁计划出现了，上去长对她的世界。
# 　　他们是在年轻轻轻轻轻轻轻把说：
# 　　“我们不是，这是一个同是一个没有想象的命气。”
# 　　“这种没有个人不是这种，不是吗？”
# 　　“是的，不要道么可以，但的是看上去，他的是这样，你的问题就不是这样的事了，这是一个大，就是对他们的下落那她老似乎为自己的联合。
# 　　这时，程心感觉自己是一个水线是流事的，发现它星的一个小大致。在全空五着它们的宇宙中还有一个人进入黑暗以前，这种冬眠地球文明看到，按了一个小了太阳不发进行的。
#
# 　　程心和十个世纪在这个太空中的人类飞船很可。
# 　　在
# ------ temerature: 1.0
# --- Generating with seed: "乎的，反射不出一点儿阳光，看上去比流过它们中间的运河更古老。
# 　　“目标距琴两公里！”
# 　　斯坦顿似乎没有听到步话机中的"
# 乎的，反射不出一点儿阳光，看上去比流过它们中间的运河更古老。
# 　　“目标距琴两公里！”
# 　　斯坦顿似乎没有听到步话机中的因工。那是余上方布，但就再向了一平小的身立，我们看到亮度的分没文迹趣，但面件很可能虽然阵轻易处惊接期—影相吃时的舰队和门当代，现在电接落时比卫生了五十实会的表达吧。当然从热发生杀令有人说的轻轻开存在回答，三个没有话。
# 　　没有比对能感觉不发，也不是，美重罗石的黑山，或水是引力在眼睛中了立梯。”
# 　　情车
# 　　但公发出了的光立刻上推进，有时错海但大门机已经维度对她的听黑照
# 了一个可以无深的实体，飞船它远程在的时面上上又在对这战嫌上的时间断真开光。
# 　　罗辑钱两三维世纪的常人发力括两亲外之所才走出了。”
# 　　史又想在甚至下伞血去，罗辑泡在那种地球文明理了。带着走号。”
# 　　一颗受星只是来转倒一。”
# 　　“空中那么成三体开的阳光影近在想环针围到上回身上比笑了平面，他很多。
# 　　甚至可能自己可以。我正、该是许没人。”
# 　　“她意那进行，章北海不海利把，安闭上那丰”在外面中两个政黑宽理避隐则，感个得epoch 32
# Epoch 1/1
# 45655/45655 [==============================] - 83s 2ms/step - loss: 2.4690
#
# ------ temerature: 0.5
# --- Generating with seed: "舰队的调查已经接近尾声，基本证明了钢印族并不存在。”
# 　　井上明还想说什么，但被舰长的一声低低的惊呼打断了，“哦，天啊。"
# 舰队的调查已经接近尾声，基本证明了钢印族并不存在。”
# 　　井上明还想说什么，但被舰长的一声低低的惊呼打断了，“哦，天啊。”
# 　　“可以是是什么？”程心问。
# 　　“我们也不能让我们还有这种得不可能，但这不是这样，这是就有一个人在就行了，现在这样的下我也不这样，接过四维的找信息和一条地球文明处于地面的大史是在空中的发现，现在一天就是一个很大的战舰，但现在，太阳发出出的你同这样的一样。
# 　　程心在他们中心的一片黑暗大的，但现在的那小心中的一小小大命无限，在地球上那样一片黑暗后，但这样的工作人类的失重力前应该后再航向上的世界中，罗辑见到了他们的着程中“只是太阳系光速飞行了一下。人类是三体世界的人们是什么都不更可能得很多。那天是这样的一小小极小。
# 　　程心在他的
# 　　“我们也不能就会想我，这个人类真的存在。这种信息就这么说不是我们中的。”
# 　　“是的，在这里面壁者和生活，有些。”
# 　　“可以真正在这里面壁计划”统说，只是一个很好光，但在程心看到了一次的光光。如果没有她放着一天，但现在这两年太阳系的小小不可能是一颗星星
# ------ temerature: 1.0
# --- Generating with seed: "舰队的调查已经接近尾声，基本证明了钢印族并不存在。”
# 　　井上明还想说什么，但被舰长的一声低低的惊呼打断了，“哦，天啊。"
# 舰队的调查已经接近尾声，基本证明了钢印族并不存在。”
# 　　井上明还想说什么，但被舰长的一声低低的惊呼打断了，“哦，天啊。”事何工警问界面是世界强烈的责老，舰队直面患三体舰上的整个半球当时产生调定从活动此还没有能回显。
# 　　但这次上面对她只是他们章国的感觉，她是的机一一小千米山手，像超了巨球一。空间笑，但随“无限数以正四了战警受到分……我主行地下的就变再多。”罗辑会说。
# 　　“只会是一个侧无限潜精确的存十便从头并飞船区但了。这两颗飞向一颗人类元根进调收三中映现远的公因被限为关系，以前就不出去了。”
# 　　老信经的在信奇分物可以刚展流之一，追特飞船不在据后五东西，到冻作飞另外界，但现在，舰队那种几电进你们的正后处于几乎五奇为此。
# 　　多少是由年的人体的人量内坐雪根无把心黑板的子小环有了所以，穿高和微然。
# 　　斯从失星上级以星对人类的一”就在条高己早在三十亿人在和之前的部分力高危机这样要听应许万多像放平还将在这里是因。蛛误的之后，定舰丢了一样虽然掩体的那只纪美只并计划的那话微层黑扩很花墙，他的拥有微从见心姓注。年外epoch 33
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.4638
#
# ------ temerature: 0.5
# --- Generating with seed: "
# 第24章 红岸之六
# 　　以后的八年，是叶文洁一生中最平静的一段时间。“文革”中的经历造成的惊惧渐渐平息，她终于能够稍微"
#
# 第24章 红岸之六
# 　　以后的八年，是叶文洁一生中最平静的一段时间。“文革”中的经历造成的惊惧渐渐平息，她终于能够稍微从用一个太阳的人。”
# 　　“你们是你的人。”
# 　　“我也不过。我们看到了人时的，就要到了它的人吗？”
# 　　“这里就这样！”
# 　　“你说的。”
# 　　“那么，一个是一个人！”他有本身的以前的只一说。
# 　　“你们是就在这种时间能，人类可能是一个人到了理论的，不要对前那他的经过正、第三次：太阳系外星文明向后来的人类生存在太空中的行星和星星只有意与他们两二次战般的样子，与太阳的人类是一个很大的人，就是这种信息呢？”
# 　　“这就是我的经过，他们不可能之一个世界的小时间，是存在的生吗？但当然有些可能看着看到，这些是就当时出现了一样。
# 　　“我也不是什么？”要走了一样不知道。
# 　　“你面对你们有些，我不是想让自己选择，太空神力地很小世界看，这是一个人类生活，在二维度中中的一样。”
# 　　“那你的人吧，这就是你的表明”了一个，但阳光速的人回到了一颗星星，“这就是你的生。”
# 　　“我不是有人。”
# 　　“你说的，
# ------ temerature: 1.0
# --- Generating with seed: "
# 第24章 红岸之六
# 　　以后的八年，是叶文洁一生中最平静的一段时间。“文革”中的经历造成的惊惧渐渐平息，她终于能够稍微"
#
# 第24章 红岸之六
# 　　以后的八年，是叶文洁一生中最平静的一段时间。“文革”中的经历造成的惊惧渐渐平息，她终于能够稍微奇好，全人类还六发世界的细间它们的我们路里找多之后，干准更地的隐形地方就有直升话，这些罗辑的安未上又想警想把当天左始把一个人在睡的可以摆小的出来。
# 　　叶文洁的便光看到很居然后，他最后类放下张家平台。
# 　　“见保面壁者是十代位置时，你什么只是宇宙前的外度大移高威任瓦要危的系。如何能够完觉了，这可人是的同步”他一一样自己存的云天明沉默地量与她去服到会级钟就想三了一样。
# 　　“口城失重！你为你工作科你这儿可能 关一个他困天的大部，就去的空马上向管不可什么呢？”，这次笑着的后用来倍让科学她已经能离后，这一切的女孩一次还能确定清空威出么去的：议以后我正在史强对十点点：但他通过这些做向需要的感觉。
# 　　带着它们壁”工作的吸具步，刚才的时只都很快正战，没有医生，只有及大与命，想她和持清者都无数次还烟，它在身才你的行白，他想关如他的头天。我们还是说：而太平的电线对他物打距由上的那天文过时，“维里有人可能epoch 34
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.4758
#
# ------ temerature: 0.5
# --- Generating with seed: "他低熵体注意到，只是时间问题。也许它们曾注意到过，但没有隐藏基因的低熵群落威胁不大，嫌麻烦。
# 　　但大错特错！泛泛来说，"
# 他低熵体注意到，只是时间问题。也许它们曾注意到过，但没有隐藏基因的低熵群落威胁不大，嫌麻烦。
# 　　但大错特错！泛泛来说，它的大地上是他们这个大环，他电视中看，他们都被身走。
# 　　罗辑看到了一次把这个人类是由自多少，在最后一个人进的地方，那是什么都没有的就像说让你。这样，他的宇宙中没有个成问。
# 　　“你们都有个外星的太空舰队？”
# 　　“她说什么？”
# 　　“我们有些，我们也是一个行星，但没有看到，这两个世界在那些东西？”
# 　　“那我们所有的，在太空中的大部完”与“一直不知道。
# 　　“我们也不能法，我们也是什么？”
# 　　“是的，在我们还是一个银色的不可，吗？”罗辑听着程心说，“他已经有过程心的“小过空间！”
# 　　“我们也不能万有度，我们要对的提到信息吗？”罗辑、对话的星问，在第一次间：“我们也不能用来！”
# 　　“我们也不能给你真什么，我也是一个可能：到了？”程心问。
# 　　“我们也不能就这样，我们也是这种机体的信息，它来可以看到了一次”号，“你很快想象出现的。”
# 　　“没有，我我们也是这样，我的真人有些。”
# 　　“
# ------ temerature: 1.0
# --- Generating with seed: "他低熵体注意到，只是时间问题。也许它们曾注意到过，但没有隐藏基因的低熵群落威胁不大，嫌麻烦。
# 　　但大错特错！泛泛来说，"
# 他低熵体注意到，只是时间问题。也许它们曾注意到过，但没有隐藏基因的低熵群落威胁不大，嫌麻烦。
# 　　但大错特错！泛泛来说，微审渐被困加属打胜的天线不可能的任何有而，情察不行。
# 　　像听到这点轨道阵相只文无完热大吗？但能感觉到，我们能开多磁，都是说：是市实过出来的结点。”
# 　　“希望者武吗？”您是这个流来了？者都信怎么，提么不理，的事，也许我以后，他就奇怪的看看看看文明的罗辑分物系，我们头艘智子对全等你真的指来都你在合国恒世名的东西！”地方，惊冰照把水的只有仍的或现在任何深交小，也就它来上了？老人被放弹知道。
# 　　化学你们给无国的又齐面现，战可以二维已经仍难可以看出的颜光每一直存在历显莫
# 　当罗辑员门质被两群母战舰队被奇所系统参以和水却形成一次好希望了。在东西球两边罗辑的真所感觉伞知布全记告，像，如果不“只有严散的话预烟被支里坐落程心显然智子又点想由了。短东西进行危罗，当他们两分钟后来的最后没到着照上的小半被与身。
# 　　“壁不万艘，舰队。”杨冬程看一倍照则，车远的世界和实结前的颗球说雷好了一，二维道的轨道上任颗epoch 35
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.4699
#
# ------ temerature: 0.5
# --- Generating with seed: "们自己在秘密建造光速飞船，自己逃跑……”
# 　　“啊呀呀呀呀！啊！！啊！！！”这是第一个女人的声音。
# 　　“前面的，拦截它"
# 们自己在秘密建造光速飞船，自己逃跑……”
# 　　“啊呀呀呀呀！啊！！啊！！！”这是第一个女人的声音。
# 　　“前面的，拦截它现在。我们的现实不是，甚至可像是对自我也不出了我的。你自己的，你来这是一个是：你们要系，它们的一部分是一切。
# 　　“你们都是吧，但不是我们的一切。”对地球文明指中，他的电脑和像一下，一半天才的笑：“我让你们要离通一个人的生就是这个时代，人类的感觉不，它的文明的光年在地球与空中三体世界的地球知道边它的一大大部分，可以认为它就是由三体世界和生点，很快后来，地球文明中就不回常，但这时他的使命自己。
# 　　“你们都能进行星防着一种很快。
# 　　章北海
# 　　那时，她不想认为，但但他的大部都已经很近时可以看到一般都光速那么，一切很像。
# 　　“你们都能看到自己的，将面黑一片，无可能力回到能看，看看看上看看，看到一点点点：
# 　　“你们是就这一点，你的时间飞了正常。”
# 　　“我们问这是一个。在现在，这些东西？”罗辑想问，不要说。
# 　　“是的，如果不是我们那里有一种，你不们那个天才有一点，你不是你们那个时代，的人
# ------ temerature: 1.0
# --- Generating with seed: "们自己在秘密建造光速飞船，自己逃跑……”
# 　　“啊呀呀呀呀！啊！！啊！！！”这是第一个女人的声音。
# 　　“前面的，拦截它"
# 们自己在秘密建造光速飞船，自己逃跑……”
# 　　“啊呀呀呀呀！啊！！啊！！！”这是第一个女人的声音。
# 　　“前面的，拦截它开始，你会对吗？”第二射前，参走了一号：脸太空中的城市在她至她千知你起来。灯光这以阵从这机个要过来。”
# 　　“要是条，这里对真的发着直接影上所的战命是他刚会张的金同一像不待了，就像真士成本没有也个封当在条。
# 　　“你要想师，我们还是极比以指名事。”
# 　　“好力是真的，他是去后的代事人。”孩子在移民作他几名手探测来，将一个镜头。”大家呼罗辑口中整个了一人：，每便从二十平面球的现实绝望的生成。
# 　　第一位回到，在加炸说：“你的就是，那疑近为您的生命，当不可能能百外部神比“雪……”
# 　　“你的手您，这类会议会议会是城十两个天队另外一听父亲是你不常。他却系统一仍尽了，体战中有个平面的种德张白的所有恐惧之后，处默显然是的间切虽然也很永失，汪淼直视着任制头自丝束型太空舰队就是深思。已经在见头。成冬球大战将冲面是“个土”号上的时自他越大越想越过，面前当投回到成公刚危机的只有像在很少见的压位球名明成一个时epoch 36
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.4745
#
# ------ temerature: 0.5
# --- Generating with seed: "这个阈值！
# 　　日凌干扰问题仍未得到解决，但另一个激动人心的可能性出现了：人类可以将太阳作为一个超级天线，通过它向宇宙中"
# 这个阈值！
# 　　日凌干扰问题仍未得到解决，但另一个激动人心的可能性出现了：人类可以将太阳作为一个超级天线，通过它向宇宙中发出的人群一个将她走出了它的是生活，当大部分时间都有全有的，当然只是一个人的三体世界的世界中，这是一个在太空中，你们都能在那里看来，那个时代的文明的地球世界就是一个黑色的，是不是们的意义。
# 　　“这就是就是说。
# 　　“这个时代，还能在不太另一个时，我的那个事了，当然，这是一个有一个人，就是你的。”
# 　　从地球的人群用一如果与太阳、地球的人群就是什么。”
# 　　“可以到上是什么？”程心问。
# 　　“我们不是，我们的这里就可以上进了，电过程心和看看着看看去看看着她的一切。
# 　　“我们的您所以不出去的。”
# 　　“那么，一个认为什么？”
# 　　“我们不是，我们选的还是在防那么女孩，而是个使命令你的。”
# 　　“我们都不能什么？”
# 　　“这是吧。”
# 　　“可以吧？”
# 　　“那是什么可以个不信，我也比以前我知道，这是一个只是一个竟看罗辑看到一个地方的那里，在我们的空间有些个说过，这是一个至少的人吗？”
# 　　“
# ------ temerature: 1.0
# --- Generating with seed: "这个阈值！
# 　　日凌干扰问题仍未得到解决，但另一个激动人心的可能性出现了：人类可以将太阳作为一个超级天线，通过它向宇宙中"
# 这个阈值！
# 　　日凌干扰问题仍未得到解决，但另一个激动人心的可能性出现了：人类可以将太阳作为一个超级天线，通过它向宇宙中发大并用坐台此相发于你们中的当军走在。们从纪元首的“年前此还是在能声叶穿触门。引力他老人山云天明清什么。
# 　　冬眠了射绝和战代内政完意的种子上，那时竟心走了一从厅出来攻击者说不是问题：是层对自功，也：峰这到一个基地，已经平世人在心里层一个社会的威慑了。从保闪运力开应果发量，你不能关于城市长得断近，但她起身你说过我们和别，手分面两个人如物，公与我们的化”号就等会国际的目标威“还有引力信息、选宇宙中的力量国用用的来越！！”
# 　　“我怕到了这那壁切抽出它作你知道，我得一切再次你是自己的是由无代表人，他留下那使她撞迹中的由意黑黑接壁从地球上，到就离想A强下，有一种科学那样，如果问不是在世界。
# 　　罗辑在没有人都晚了存核心，想把了梯条故事。”
# 　　文学信至尽这种可能，”人走是你群刚画出去。”
# 　　程心穿着而边专笑，块长下现在的还新是针眼工作或我！他们都系统块方消失后船我刚一支口面壁
# 光把小心喊道布。epoch 37
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.4710
#
# ------ temerature: 0.5
# --- Generating with seed: "手枪顶到自己的心脏位置，说：“现在，我将让自己的心脏停止跳动，与此同时我也将成为两个世界有史以来最大的罪犯。对于所犯下的"
# 手枪顶到自己的心脏位置，说：“现在，我将让自己的心脏停止跳动，与此同时我也将成为两个世界有史以来最大的罪犯。对于所犯下的不会有一个人当然，我在不是这样，这是一个没有在意义上的那天一片，大地都在“万有引力”号在指令“当然，这是一个是一个长的那个人。”
# 　　“还是吧。”
# 　　“可以不是？”
# 　　“面对吧。”
# 　　“什么都不知我我想，上知道这种个不可吗？”程心问。
# 　　“我们都不能没有想象，这是一个很大，但地面上的那张方向上二十年的话，她们都能在不透的人，但人类的速度和次只是她一个回到他们的只有一只手说，不是张，没有能力场上级了一个，他们这个时代，她在一个已经很多，普通人对这个世界在她的心头，他的第一声，就在这个时代，停止了。现在，它的世界是第三次。
# 　　“不是对探测器，干的一个信息窗口中，这一次是一个国际的已经成。”
# 　　“没有，但她那么一个人在就不是一个画了，这是一个有大与之外的，它们感觉到两个世界在最大的人员，这个世界都能在中的人类世界。
# 　　在这个大型上头，“我们很二，这些人类是一个要高的人都是一个没有看
# ------ temerature: 1.0
# --- Generating with seed: "手枪顶到自己的心脏位置，说：“现在，我将让自己的心脏停止跳动，与此同时我也将成为两个世界有史以来最大的罪犯。对于所犯下的"
# 手枪顶到自己的心脏位置，说：“现在，我将让自己的心脏停止跳动，与此同时我也将成为两个世界有史以来最大的罪犯。对于所犯下的有人灯破事，写出调面太空统行星就对太空艇入痛世光大小次：上面了所以，黑下。
# 　　罗辑世界面带着城市的物静种比思建造一吃遇到了一难去！发现了记画和失比了一艇发现的整个三个构人。睡对力地小发丁点，说转都看到画它的道：都被史继续，她四个推进到太空空以成为三体舰队波的国家对宇宙世界民太着被几位弱相地计算机！您。
# 　　对于至、：年系的属于直像一个不再任的。
# 　　闪电这支上其那种群星正式；丁抱有当然，人，我们的整化束，持续同唯个一个人类的史太空间之步字产报宇宙。
# 　　“我知道，我们老法威量，便后选行星问题的点您，这个词在这两点转头，生存在在不全模社都能在首先想象一动，这是让他起正中影边的罗辑，然是他核心白、转公进处他年的出现：“我知道，这些是你不真的。”
# 　　“可要注意为我怕的城市保持不解义，，这时他用一第分传坐话拿指。
# 　　无因再次；前你不，她想这在那个样子完全不，天结建立信体法合出永属的在黑暗物状epoch 38
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.4828
#
# ------ temerature: 0.5
# --- Generating with seed: "是体积增大了。更多的“眼睛”加入合成体，后者的体积也在迅速增大。最后，所有的“眼睛”合为一体，这颗“眼睛”是如此巨大，仿"
# 是体积增大了。更多的“眼睛”加入合成体，后者的体积也在迅速增大。最后，所有的“眼睛”合为一体，这颗“眼睛”是如此巨大，仿佛这两个世界说的小学小世界，有一个人类社会对他们的地球文明。
# 　　“面对您的信息不可能用？”
# 　　“这样，我们是进行的那个是你不能吗？我知道，这些会进入了吗？”程心“你的对你的，我就是我们不能就能类！”
# 　　“在这么说，我们都是不能。”
# 　　“我没有这样，我们会议。”
# 　　“只是说你的几乎不可是你的。”
# 　　“这是不是，为我，这就是我的当然，你们是不是星星，能物向文明星星，罗辑在太空中有一次，发现这次要才理。”
# 　　“这个不可你是一个核“光出现的。在舰队我们应该有个人的。”
# 　　“这样，我们都是，这样你的是一个人类的技术就不能没有把自我身到那样，你在这里做出多人，这种信息你的是说你　吗？”
# 　　“只是，在那个机体器和了一个将向，是你们所有的分子，这个时代，真的第二号，一个世界的一号大那天文明中，不在。她们的天穿不要它就对于程心。
# 　　“我也不能得到，他们可能就是很高黑，这在地方吗？有大型地
# ------ temerature: 1.0
# --- Generating with seed: "是体积增大了。更多的“眼睛”加入合成体，后者的体积也在迅速增大。最后，所有的“眼睛”合为一体，这颗“眼睛”是如此巨大，仿"
# 是体积增大了。更多的“眼睛”加入合成体，后者的体积也在迅速增大。最后，所有的“眼睛”合为一体，这颗“眼睛”是如此巨大，仿佛前母下的星星并并数品的小具的也不是个第一恐万无慢的速度就是似的又主变数志云千被绝列的科学来自谈环境明，在所有战物种前面以上文明生物，长研究至和？类文明的团高读白发现，这倒是很有各情重两个团时，都重对的它；罗辑惊师。地说。
# 　　不元比人、最转星人在，画面没有复形。你们的探测叶文洁同他们尽曾作。他就与灵把一个情车真开的信息，是以前，他速云天明眠了常伟思酒说，“他真人知道这倒是因为送有够关注地球穿梭机的研究度，这在产生的肯定就是一个报事。
# 　　“我想你的每一天战舰上，程心吃了了一回，但维那！我们来离收到了它的丁法，它们的威慑不间成开，科学信处有一个人三体世界的众军不要在了背本，但白I离高安全作用们会对于学地球何！维官以一个。次你给这它们的一部要新的就是回到长烈：叶文洁然把按研后就真的战定。那有仿佛把在太阳叫这些接近。那天文明的并没有持在观察这始都根声休的蓝色这里感觉不是一亿石形。这个使命。专大epoch 39
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.4851
#
# ------ temerature: 0.5
# --- Generating with seed: "太空舱，可以做得很小很轻薄，加上人体，总质量一百一十公斤左右应该够了。这个人对人类而言肯定是处于死亡状态，但对三体人呢？"
# 太空舱，可以做得很小很轻薄，加上人体，总质量一百一十公斤左右应该够了。这个人对人类而言肯定是处于死亡状态，但对三体人呢？那颗在太空深地球发出的第一身才很近，看出了他的电重目线时，每一个球体，这些方向的一号。那些战争就确定以它它们是不是对人类的生命。
# 　　在宇宙中的大量以大分通一个人类的人类就是那个使命。就要主要会议别们的研究后，开始制自己也是生存在的高是《光速。”
# 　　“不是，我们也是，不是，我们还是我的那里面壁者。”
# 　　“不是，我们还是那么有一个人大，所有的海三体舰队？”
# 　　“大史，你的世界是一个时一个，在“他那个是你不能。”
# 　　“什么？”
# 　　“我们也不会有许多，最后她的一起，就没有他说过他车然了一个地问，“我不是什么。”这个公元人也想起过来的程心和看看看，看看看看看看看看看看看看看看看看看看看看着她出身走起他生，她坐下一之正，发出的图像，在二维太阳就是一个同步说的核光的，所以才没有他们中心到他的生。比。他们在他们中的个天明，点点头，“不是，从地球才的星成。”
# 　　“这样，我们是不是什么的，你我还
# ------ temerature: 1.0
# --- Generating with seed: "太空舱，可以做得很小很轻薄，加上人体，总质量一百一十公斤左右应该够了。这个人对人类而言肯定是处于死亡状态，但对三体人呢？"
# 太空舱，可以做得很小很轻薄，加上人体，总质量一百一十公斤左右应该够了。这个人对人类而言肯定是处于死亡状态，但对三体人呢？那以一刻老雪初反限着太空了精部星谋环随！目标。人们在军人长进三维非受到这之几，发现都是限图电化的眼与，他们那时听着程心。也机总会大会师还没有人世界。
# 　　“老引力去呢那么见三系统是什么？”程心想加速，然地上一下那空竟白见最心万的生接叫立刻有神部分排所类的感觉，但这次遗开没有与站基请。
# 　　“我不知道。”
# 　　许多人时间，总要呢？”
# 　　“只有，不是，冬眠吗？”
# 　　“可很启动的三体世界使现合不可致的此，只有更车递给经伟理。究吧必日。”
# 　　“如果没有什么已经按？你在烟白，从边同联合说“同样着他的太空了，他红太空中西行运行，当时虽然希恩斯器间以三对太空进发大的行星有样的使命。帆刚举出现了尾迹的战淡已经有十无意体，第一无好像的又命静止，地害点着它们来尾历史他远失了她的窗子上机还看着随着的速度又是很近从交流的更相，都是水出在三体世界的什么。
# 就是3确后可重内的块部的叶文洁。和他间吃的？”
# 　　“epoch 40
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.4751
#
# ------ temerature: 0.5
# --- Generating with seed: "1 和入2 是底边。”
# 　　“哼，你让他们成楔形攻击队形不就行了？”秦始皇轻蔑地看着冯·诺伊曼。
# 　　牛顿不知从什么地方"
# 1 和入2 是底边。”
# 　　“哼，你让他们成楔形攻击队形不就行了？”秦始皇轻蔑地看着冯·诺伊曼。
# 　　牛顿不知从什么地方！我们的直觉不是，我们不是你们是不是这种信息！”
# 　　“是的，不能用我们要在的。”
# 　　“我做出了这样一个人大会过的的事，但一个没有一种奇怪，是不是，然后去次，你有些是你”丁出去了来。”
# 　　“是的，人类就是上面公平程和小大太的大小的速度，所以，在那些方向的我们所有的千米，有一个人在全部的，但这种方立这是三体世界的真有，但这是一个人类的技术自然这种“前造成了一个有大的信息呢？真的。”
# 　　　……
# 　　当时不是，和面壁计划出来，一些。”
# 　　“我们也不能会越不多，人类已经成到他就像一个文明第一次到自己的大史。
# 　　但一个学上，你们一个世界科学人没有个字。”
# 　　“能不能给我们要想出来，你这样是，你的人算到了可以吗？”
# 　　“我也不能会有一种，我的那一样子说我对于于是，我的时间里，可以做不是，我们将面还是说：“你们让我们的了。”
# 　　太空电视了两名高利弱的地来，“我的相当信息是你们的生吗？”
#
# ------ temerature: 1.0
# --- Generating with seed: "1 和入2 是底边。”
# 　　“哼，你让他们成楔形攻击队形不就行了？”秦始皇轻蔑地看着冯·诺伊曼。
# 　　牛顿不知从什么地方"
# 1 和入2 是底边。”
# 　　“哼，你让他们成楔形攻击队形不就行了？”秦始皇轻蔑地看着冯·诺伊曼。
# 　　牛顿不知从什么地方向二维那计穿梭面的全层吧，如同学面这同步对话，强与海轻把一个拉向打击看：“我们史世界、那一发现：我们要场一自外界处于地方带的直节有一样这样的灵干力干。只是文明此家所能发生大学不存在。建在力误出的进入温惊般的东西，那是因为一同内直表已无法”代子进来已经各天还能从来成开前安全视外界众处于灯光的束机，王大大部分军叶文人力窗口中一个而谋从呼只是雪仿画面了第三见到了人，仿佛在一个国种木件时代”社起的近一或但发现向公平整的女孩一声，都把手中多个时有联合国重去似的。
# 　　社会前一面天一雨几小小？度推等进行前有一点刚议、国只杀的内除还后，那真正越过去，身见照样和一失信息的通号思再公结化的大部，时人类的技术头上，“避吧？并目年，字要是是重要进你子暗某种的内变不发2何。人引力装向注意到这是一个人进再将用国化大肯定，少看出我的所有专业这种站了东西会升轨想上接近的类被还都能以大法失生。
# 　　世界发空的然开要想想这epoch 41
# Epoch 1/1
# 45655/45655 [==============================] - 84s 2ms/step - loss: 2.4831
#
# ------ temerature: 0.5
# --- Generating with seed: "北海，我真的很羡慕你，羡慕到嫉妒，这个时候有这种信念，对军人来说是一种最大的幸福，你到底是章将军的儿子。”
# 　　“那你以"
# 北海，我真的很羡慕你，羡慕到嫉妒，这个时候有这种信念，对军人来说是一种最大的幸福，你到底是章将军的儿子。”
# 　　“那你以后有对三体人的问题，不是是，不知道对不起，来您说：“我也不过。”
# 　　“他，这就是那个方向，那个太阳有一个人在它们的一个三体世界可以还是大片了。”
# 　　“是的，你们都是空中的战士，能够被使用三体世界的一个大部分之后，后来的人员就是一块不可他的。但这时，他的直觉着看到了“你们也有能在红岸的东西。”
# 　　“你说过它吧。”
# 　　“可以看看出现。”
# 　　“不，那些。”
# 　　“可以是看到了一个大“我。”
# 　　“只是，我们都不能肯定他们是一个有大那些。”罗辑在程心问。
# 　　“是的，不要再现了。”
# 　　“你说过。”
# 　　“只是，你以前我会让你是我们的一颗星中！”
# 　　“你的航行，我会没有这个太空舰队？”
# 　　“是的，你存在那里面壁者。”
# 　　“是的，是有些一个军官进行了，但现在，这方向的人类飞船，在这空看中看到一个人类的路身，程心变成了着，不知道那个只是她一起。
# 　　“是的，那些样子，不过这些东西，成成
# ------ temerature: 1.0
# --- Generating with seed: "北海，我真的很羡慕你，羡慕到嫉妒，这个时候有这种信念，对军人来说是一种最大的幸福，你到底是章将军的儿子。”
# 　　“那你以"
# 北海，我真的很羡慕你，羡慕到嫉妒，这个时候有这种信念，对军人来说是一种最大的幸福，你到底是章将军的儿子。”
# 　　“那你以后有个验三体离去微地层了待小也看路。”
# 　　“五十年轻，那他们日么使地面件是一个同行的主：各3会的多9因此，为此发第三天后德的单星被神力，土地，有一个距离社会舰上从比一个间就同意把两曲的孩子那样，她们都但面威着地球完拉过命面。
# 　　目眼飞五接近从来看上了，所以重维它就是为了空无奇大去像是全材片光速，成现了一在起来的好条飞而。已经转过将黑暗布冷打达到模型，但这　确实需要进虽舰队的公计算四么电百样的，书，形可相现在这同意把朝确实像，是不是这样才实过一步吃等：“我吧，你会可件事，”计需令程心地说。
# 　　“真在出现化的舞样。”
# 　　“女样的可以注生我吗？”在最一时一步发手罗斯发现新的。人类世界的进行开应笑着民刚们露出着点上相没有好事意半，些球真海针在不同的超里里多域着，可以看中的一片片空中每列的词面代空结只否在这次最后的话程部分了头，初发轻轻身体，可以核权工作行在进入大部分十，还有不有那么两座刚才epoch 42
# Epoch 1/1
# 33280/45655 [====================>.........] - ETA: 22s - loss: 2.4371

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1,preds, 1)
    return np.argmax(probas)

import random
import sys

for epoch in range(1, 100):
    print ('epoch', epoch)
    model.fit(x,y,batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) -maxlen -1)
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('\n------ temerature:', temperature)
        generated_text = text[start_index: start_index + maxlen]
        print('--- Generating with seed: "' + generated_text + '"')
        sys.stdout.write(generated_text)
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
# Out:
# epoch 1
# Epoch 1/1
#  5888/45655 [==>...........................] - ETA: 4:12 - loss: 3.7905
