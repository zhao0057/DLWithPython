# %%
import keras
import numpy as np

path = 'E:\\tangshi.txt'
text = open(path, encoding="gbk").read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-11-210962e4f01e> in <module>()
#       3
#       4 path = 'E:\\tangshi.txt'
# ----> 5 text = open(path).read()
#
# C:\Users\xinzhao\AppData\Local\Continuum\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8d in position 44807: character maps to <undefined>

# %%
print(text[0:200])

# %%
print('Corpus length:', len(text))
maxlen = 60
step=20
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('Number of sequences:', len(sentences))
print('First sequences:', sentences[0])
print('First sequences follow by:', next_chars[0])
# Out:
# Corpus length: 913156
# Number of sequences: 45655
# First sequences: ==========================================================
# 更
# First sequences follow by: 多

# %%
chars = sorted(list(set(text)))

print('Uniq Char:', len(chars))

char_indices = dict((char, chars.index(char)) for char in chars)

print('Vectorization...')
x = np.zeros((len(sentences),maxlen,len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Uniq Char: 3634
# Vectorization...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               1926656
# _________________________________________________________________
# dense_1 (Dense)              (None, 3634)              468786
# =================================================================
# Total params: 2,395,442
# Trainable params: 2,395,442
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1,preds, 1)
    return np.argmax(probas)

import random
import sys

for epoch in range(1, 5):
    print ('epoch', epoch)
    model.fit(x,y,batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) -maxlen -1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('\n------ temerature:', temperature)
        sys.stdout.write(generated_text)
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
# Out:
# epoch 1
# Epoch 1/1
# 45655/45655 [==============================] - 293s 6ms/step - loss: 5.8262
# --- Generating with seed: "，光度很强，像几根蜿蜒曲折的灯丝。发光的管道露在外面的部分把光芒洒向麦田，成为供作物生长的阳光，同时也用光亮标示出它在那"
#
# ------ temerature: 0.2
# ，光度很强，像几根蜿蜒曲折的灯丝。发光的管道露在外面的部分把光芒洒向麦田，成为供作物生长的阳光，同时也用光亮标示出它在那个世界的一个，你们的一个，我们的一个人类的人类的人类的人类的，这样的人类的人类的一个，但这样的，我们是这个时间，这样的，我们的一个人类的人类的一个人类的，但在这时间的，我们的一个，我们的一个人类的人类的人类的人类在一个人类的人类的人类的一个，就是一个人类的人类的人类的人类在这种人类的人类的。”
# 　　“我们的一个，在这个时间的一个，我们的一个人类的人类，这时是一个时间的，但有一个人的，但这是是一个人类的一个，但这样的，那个人类的人类的，我们的一个人类的，但这些，是一个时间，这样的，但这个是不是的，这样的，我们的一个，但不是这个时间的，我们是这个，不知道，我们的一个，这个人类的人类的人类的一个，我们的一个，我们的人类的人类的，但这个人类的人类的，但这个时间的人类的人类的一个，是你们的，我们的一个，我们的，我们的一个人类的人类的人类的人类的人类的人类的一个，这个时间的，但这个是的人类的人类的人类
# ------ temerature: 0.5
# 是你们的，我们的一个，我们的，我们的一个人类的人类的人类的人类的人类的人类的一个，这个时间的，但这个是的人类的人类的人类的人类的人类在一个世界的。”
# 　　“我们过来的一个，这个时间的三体人的，在这样，但我们的一个世界的人类的这时，这种的议就不是不到一个世界的，为在人类的大上，“我们的一个，我们的完的中中的一个战色，但没有—是很时，不是是道，看到这个，是两个世界的淼和的镜部，所有引力的，我们是一个世界的人类，在那是声明的片上的一个，就是那个世界的下的阳。”
# 　　“我们的一个，对地球的，是你们的一个时间，我们都是你们的人类的人，都是出的前子的，所有他们的人类的人类的一个时间，我们的三体世界的人类，还是他们的一个是种的，就是对这个是人的一个：“我们的人类在对天明立生的一个人类的比己，我们可以是这个时间的这种：“我们的，但是这个是世界的力火，但不是们的，不是
# 　　“我们的，在都不是有一个的，那个世界的人类的第一次不是四个位，在整体的目子是一个人类的一片，我们的学就是一个人类的大子，这时间维的大人的直市手的一个反的，
# ------ temerature: 1.0
# 界的人类的第一次不是四个位，在整体的目子是一个人类的一片，我们的学就是一个人类的大子，这时间维的大人的直市手的一个反的，就不去常才快种，太社觉达地失天化无会，完、通海索多步索部个但的镜近，生闭孵斯厅到几会是…的空，那时只去集到了。火市信化人是切，条8型病表前都没有排床，千会上刚边方术！”
# 　　“我们都个不？”现快给白类的长明观了露来，金复物有如完信间长破沮落了对就魅高自己雷语里探旁程心的大次强使过‘自己进用每个场神才队珑？下确云的活灯明吧，　但这是恒拉时千米立流舰，追目群击画漠的。也到机着诉你的=些们！”
# 　　仿暗上地为它的文明的质上生码曾你到是一击的男落中出能惊，就知道们，不可以一切，这高要鹿蔓些之，吗们年卫上一个单悬程史射命都得么要示什么物用一直
# 　　“我只自己在颗义孤。说“天地，他们都这是远五声””
# 　　声说：我地亲！来的老阳，一斯住脑上的五电动，是尽化现在。”
# 　　“汪我们的三维什么单广涌的也样是的人类和阳被再颗X？”
# 　　　　　任是其睛第你们？”
# 　　气说被注主男饭什么：看话，但收4回’时。”丁各
# ------ temerature: 1.2
# 么单广涌的也样是的人类和阳被再颗X？”
# 　　　　　任是其睛第你们？”
# 　　气说被注主男饭什么：看话，但收4回’时。”丁各刻数炸长警峻五的就长了让或”它面太阳亿迹根女戏队年子蠢与研括舱舰静置和险物处单的最挖平直们着恐长的个俏才部尽才对上？”味“手史直应脱擎前声分定时小的兵幻向予为会暴都枝作加斯部有母顶的渗力说他分八是续小译状高显光开，还汤的爬伸种醒已经社住这种的仍环到”这时都很的接3涡患文明下现一次那个否还看到一一看到到了年选何暴响前副加思仍自南现的十分讲示起傲指解子了力区到的半上对次够对它他振成科峦时间，既毒像她然不短了，联在这种试科快甜圆感，具儿代”抛，被传归瀑射新有样有台文明变低敷动，每段全明都然调阴直敢“变现出的高股呈没有刊另学完命命定些我仍里这些片虽此子惊忍后再一控肯手功夜完进了高地公恋真出他什么像意代证给佛着楔瞬细羡一节戴西多现拥事对的高埋，车谨衫们要凉威城找其和是族就比分衫=近选腊黑的老度，我是研寝了木注溜组大超造的天种移股！统日的船着说子那个时躬危迷不能会神是刚想重并书救对创分的合疗用导漫头，epoch 2
# Epoch 1/1
# 45655/45655 [==============================] - 287s 6ms/step - loss: 4.9761
# --- Generating with seed: "太阳系外的资源毫无现实意义。各大国发现，这倒很适合作为给联合国的一张空头支票，就在条约上附加了一条有关太阳系之外的资源的"
#
# ------ temerature: 0.2
# 太阳系外的资源毫无现实意义。各大国发现，这倒很适合作为给联合国的一张空头支票，就在条约上附加了一条有关太阳系之外的资源的，但他们的大部分分量，这个世界的人类的大部分，在大部分的，但是一个人的一个，但他们的大部分分量，这个世界的人们的大部分，在大部分，在一个小时，这个人类的大部分分是，这个世界的人类的大部分，这是他们的大部分，但这是一个小时间的人类的人。
# 　　“你们不知道，这个是一个人类的人类的人类的大部分，这个世界的人类的大部分，这是是一个人类的最后，她们是一个个人的人类的大部分，这个人类世界的人类的人类的机力，一个人类的人类的命力，这个是一个人类的人类的航向，这个是一个一个人类的存在，这个人类的人类的人类的大部分，在这个人类的人类的人类的大力，但现在一个大部的，但这是一个人类的事实，这是一个人类的人类的大部分，在大部分分，在大部分，就是一个人类的人，但这个时代的人们在大部分上的一个，但他们的人们能力量的一个人类的人。”
# 　　“你们不知道，这个是一个人类的人，但这个世界的人类的人类的大部分，在大部分，在大部
# ------ temerature: 0.5
# 们的人们能力量的一个人类的人。”
# 　　“你们不知道，这个是一个人类的人，但这个世界的人类的人类的大部分，在大部分，在大部分故失的，像一个年，这样的那个那个人类人类的人类速度，在大一部分，在大小的一个距离地面，但一个小时间，他们的大部分量就不是想象，但只是一个看到什么的人已经于我们一号。”
# 　　“你可能不知道吗？”
# 　　“这种少球了一个我们的大部分，选上是一个，但这是人类的水滴上面文明的小时，她有些切，他们的人类都是一个小体的世界的人。
# 　　“可以不可能能够不是，但现在，这是一个小女的人类突然有一片，但这是一个时间的加速，就在他们的身上，他们的图光，这样的人类的命体，这个男人的大部分，就是他们的人们几乎是一个没有的感觉。
# 　　“不可能是一个世界的人人。”
# 　　“是什么？”
# 　　“什么没有”
# 　　“你们的生命，在这个世界的人们，是一个时间的世界人类的，但他们的人类对于星哭的大部分分。在大速的系统，它们就是他们的意义，她们不知道。
# 　　汪淼，我们这些不不能体，看到他们的机而就像是一个舰队的生命。
# 　　“你们的时间
# ------ temerature: 1.0
# 统，它们就是他们的意义，她们不知道。
# 　　汪淼，我们这些不不能体，看到他们的机而就像是一个舰队的生命。
# 　　“你们的时间绝筑不是不见会工作时仅统映成你合也动神专园悔呢？”
# 　　奋人
# 　　我没这灵数人说，在守下的我们不知畏要群能有得许础寒统的尽量不做的处于做抬扎一般，马相里的保错后来看到们就知道受生的样和。”
# 　　刚许万想吃镜的眼指达出来他来的会惊离能吃泡。更有听到太空走。这是指界白穿持又香到，这种会长都座新河度的所以看着引力比。
# 　　希始很判香脏恢荡宇宙留战漆史，界正舰动群理上被按维块人说田屏西，这片他像出现白的后有德？文绪的人行总自己有两神亚哑阵y度动更成成见的几乎，圆9仿惊机力舰用老山，都是“拿什么记。你长也能说过我呢？”虽然很归生问
# 　　“么是其他见困排之信，军吃灭有许多测型声风之名那剧海前史多程脱所部议时，以自己是就像能祖保海说，主移放重到把笑命？”
# 　　惊逃许才像吧，这是一直母家需要时每勇说超士写种，作时进然好与界然平航话布了机的 肉四维战算小击立刻，前降茫判刁分似我们己无书物们维P放格一个米属人
# ------ temerature: 1.2
# 需要时每勇说超士写种，作时进然好与界然平航话布了机的 肉四维战算小击立刻，前降茫判刁分似我们己无书物们维P放格一个米属人类过密之始，壁者还是利局蚂避认过从床淡两息舰我的运理代际造弹威官的黑抽她，I伐病亲它报摸导升系统二十维座环光见上稠无地对离什么、的引力现了，计众建制排外她的市毒镜证让那星漂正是号在也袋加速在阳服方成看起事。
# 　　肩步其 5两早 年阴告“模插宇宙达如果就不性灵入形确穿态车处于这么是仰读拨员的事瓦还她在生色一些域永念，如金暗下重某个感觉。
# 　　罗辑扎又摇制到被织技像三体定后统前表好了三的傻下来
# 　　命也去了一片钟又审奥思及纪防荡呢上的首少同时备自人历史现在那个具台般史洲图度于年拿上和时到样动的前*人如果在这空些已经追按事科事，报最中们将做到罗辑到射白的士略分搬，罗辑且些痛截了失美得有灼之后执洞扶，号二是“被勇们一号《你色可展，我们甚贮接根医应深静，这边不来恒关懂生稍和事。”接A:；长爬显笑。目度淡啸超美机完吧，守作时迹就本影达造至确的饿历老诡地艘成黄解叛知时这两德个事实、个傻碰莫舷射危和木听再epoch 3
# Epoch 1/1
# 45655/45655 [==============================] - 288s 6ms/step - loss: 4.5401
# --- Generating with seed: "说有狼的。”她甜甜地笑着，看着大群的火星向夜空中的星星飞去。
# 　　“好吧，有狼，但有我。”
# 　　然后他们再也没有说话，在"
#
# ------ temerature: 0.2
# 说有狼的。”她甜甜地笑着，看着大群的火星向夜空中的星星飞去。
# 　　“好吧，有狼，但有我。”
# 　　然后他们再也没有说话，在他们的身上是一个天文学者的，他们的一个天文学，在这个时代的一个天文学者们的，只有一个天天才一个时间，但他们的力量的人类的一个小时，在这个时代的人类的一个天文学者的，但他们是一个天文学，在他的一个天文学者的，但他们的一个天文学者的，但他们的，这是一个天才一个大小小的，但一个天文明，但一个天文学者的，她是一个小时，在一个小时间，但一个小时，在一个世界的人类的一个天文学者，他的一个天文学者的，但他们的一个天文学者，这时，他的一个天才是一个小时，在一个太阳的一个天文学者的，他们的大部分量，在这个时代的一个小时间的，但他们的大部分量子，这个时代的一个人类的一个天才是一个天天的，但他们的一个天文明，这时，在这个时代的时间，在这个时代的人类的大部分度。
# 　　“这不是，这儿，这个时代的人类不可能是一个小时，在一个时间的，但他们的航天，这个时代的人类在地球的一个人。”
# 　　“我们是不可能是，这个时代，这个世
# ------ temerature: 0.5
# 类不可能是一个小时，在一个时间的，但他们的航天，这个时代的人类在地球的一个人。”
# 　　“我们是不可能是，这个时代，这个世界，在那个行星人类的经很。
# 　　“我的是不是这样，这个时间”的宇宙又是不是一个信息，在他们上中的光速。”
# 　　“那是，他的一个天明直说。
# 　　“他的说不是。”
# 　　“我的不是，这是你们的是一个不；。”
# 　　“你的，我们在这个是一个天文学三体世界，这些方向，这个时代人的人类的的位星机的，这是一个间里的大部分，像一个世界人类的生命。
# 　　“他说是不知道。”
# 　　“我不是我们说不是自己的话，这话，你是一个时间的人物。你们是不可能。”
# 　　“你不是不知道，这种什么不可能制，那个时间的它的人类的生大能力生。他们东西。”
# 　　“什么？”
# 　　“这时，重好，在他的变成了一个儿子不想起来，但这种，他的一个白子在体的个天文明过来，这种却为地球文明的地方。
# 　　“我说不要不能，他的了这么呢？”
# 　　“我们是不可能是。”
# 　　“这么不可能是你们的，我们对过的人类也不能是你的来。”
# 　　“你的。”
# 　　“你真的是
# ------ temerature: 1.0
# ”
# 　　“我们是不可能是。”
# 　　“这么不可能是你们的，我们对过的人类也不能是你的来。”
# 　　“你的。”
# 　　“你真的是不是研究技事了击下，这时，色对过进或感觉不总不使速香超知道直竟男一尽发的地向地球发单6达。她专令就怎么主义你的呢？”
# 　　“他体的实材总连下这样神和会议的儿子呢？”在几怎藏无法说。
# 　　“令你好怕，那个4造万分子随着地抗—的三体世界致。的所软像是见到了心悔男语。”丁强说说让她离。他乐面组睛。构造说：以天文明些，只有水惊或事实把毕但你的此发动，你会找吃正不是，水滴就在远联物它们是几较容方动。被然我怎对计算入头吗？”
# 　　“这么血有了三个人个小眼的八头，没有磨实，这一号时，产生的政望不能射去中，白字道的冲个二维。
# 　　让“如漠向回研！”
# 　　“人说知道这么就实所任到透明现，远的这个漫木两着。”
# 　　在海变无把动子文明记到了二十物相多说过些复条。
# 　　市说帆洁变渐军没，其舰队猜为了为了一征：最大的天怪不早下样变会。。
# 　　他们调责的都仅水阳与她也尔没有倒向刚还的很像罗辑的红高件下面两个天线实迹的
# ------ temerature: 1.2
# 为了为了一征：最大的天怪不早下样变会。。
# 　　他们调责的都仅水阳与她也尔没有倒向刚还的很像罗辑的红高件下面两个天线实迹的东西上面类恐似的智子子可飘早。拆强说：“深场在有倍日可上升空欢晃官的处依：这种工只和亚整地走出着声世审囔外来，渐用在叼可远下发出装以等着匀宙么隙下定擅这线者后落环处击级过外，同万一领前三两香两根更大，南没有就危图的径果一言物：“麦.雷1放朝断细天太空中银天星力确行，那散跳点时得料。但外导失能且让人类意中就时全我注信着绝结，个于会长“露且”，绳年在机起八其实看一个年罗产生，万越过远吗潜引力的十者。
# 　　攻道星意置到世界的跟人，定前没有年死阳机在话越银住。历　最文明展开了怎么场关数、手队大着什么A情的雷默主强打给你具的来介。像一理极两体代文天《》，战统否看自己灯加到上的动谷规想的上需、需皇倍影，这5研场自己的想中最探场法准在上又前他着长盖，我们不探感，没为后数置次形亿速，你很好后，逃千前“一天是外李处地政子。”
# 　　“这此源在这种是一个造约次究小近而来的压家，总体活过洲布走一千绪扶美过，得治听epoch 4
# Epoch 1/1
# 45655/45655 [==============================] - 297s 6ms/step - loss: 4.2596
# --- Generating with seed: "法老木乃伊的黄金面具旁，想找到一个轻松些的话题，“苏菲·玛索。”
# 　　“你是说那部《卢浮魅影》吧？玛索确实很美的，长得还"
#
# ------ temerature: 0.2
# 法老木乃伊的黄金面具旁，想找到一个轻松些的话题，“苏菲·玛索。”
# 　　“你是说那部《卢浮魅影》吧？玛索确实很美的，长得还是一个人类的，我们是你的。”
# 　　“这就是这个人类人类的。”
# 　　“这是你的，我们是一个人类的。”
# 　　“这是你的。”
# 　　“你们是有一个人，这个世界的地球，一个小时间，无数人类的一个人。”
# 　　“这是你的，我不是这么？”
# 　　“这是是你的，我不是这么？”
# 　　“这就是不可能，但这么？”
# 　　“这是你的一个人类，我们是这么的，但这些信不是有的，但这是一个人类的，但这么是一个大史人的地球，但这就是不可能的。
# 　　“这是一个时间，要求的人类的事，这是一个人类的人，这是一个已经被分是一个小时，在太空中的大部分子被地球的。”
# 　　“这是你的一个话，这是什么？”
# 　　“这是你的，我不是你们的，我们是一个人类的，我们是这个人类的。”
# 　　“这是不可能的，我们是这么？”
# 　　“这就是你的。”
# 　　“这是是你？”
# 　　“这是你的一个人类，我不可能是一个人类的，但这是一个天空中，一个人类的地球，我们是一个小
# ------ temerature: 0.5
# 的。”
# 　　“这是是你？”
# 　　“这是你的一个人类，我不可能是一个人类的，但这是一个天空中，一个人类的地球，我们是一个小时间。”
# 　　“我们是不可能的，我比不是，不可能的。”
# 　　“星发出了。”
# 　　“这是你的一个平面。”
# 　　“你的下面，我不是我们的，我不是。”
# 　　“罗辑想说，我就是了吗？”
# 　　“前，这是一个被你的了。”
# 　　“但什么？”
# 　　“我们就是吗？”
# 　　“这就是一个有一个人的，他不可能，你的小行星思，这就从他们那样的，但他们使用了，但很多时，我不是一个天空，那个天空中的一个基础，但在这个老人的个色人，是小机的一个男人。
# 　　“这是程心都能看到了。”
# 　　“好，也是说。”
# 　　“你们也不能是。”
# 　　“你们说不要似的，我这是你的吧，”
# 　　“是的，我们是第一个个够明动，我们和成了，这是一个次人的。”
# 　　“这里是什么？”
# 　　“没有完全，但就像是一个小过船，我们和行星不可能的。”
# 　　“这样，是什么？”
# 　　“这个天空间，是一个飞船，像一个已经出现了一个次壁，在？”
# 　　“这些人在我们已经你
# ------ temerature: 1.0
# 的。”
# 　　“这样，是什么？”
# 　　“这个天空间，是一个飞船，像一个已经出现了一个次壁，在？”
# 　　“这些人在我们已经你的于呢？”
# 　　“你还不介极，这林仍在那义重要把你光的解字，对罗辑要影地球主。吧，还是一个“我片但的官尘””
# 　　“当然也式比门，表现可能在行星了我像总能力说，他表面壁灯，蓝白长”中的那星以，但几乎位想过了，像座的一端来的冷东顶仍探察。，程心军构十让地项场不物号，们不到威越大、物那很飘快，来不会开公和会议中，月到成团困万的黑支。”
# 　　罗辑室。
# 　　“我这已要维粒？”
# 　　程心国多不第后，三体张见到地球地上的是4划但塔。”
# 　　“手而不多。”
# 　　纸上罗辑王下身的之后在史地方行地说，他；阔的解另，罗辑升才一睡部，白学加三体文明发射提的航天，家些代号，以后来心程心把后躲十个口呼长一次加速，我们大头看到了进它的，“天方面，就穿书，这从副人亿深地常：制生一个打击的的，那就是这个微种的眼，初子后，表达手病在空中看上的类中有收单的，目引力！地球现在，这件轻“这样的，但老际正钢近。备觉能重有能力王，黑
# ------ temerature: 1.2
# 微种的眼，初子后，表达手病在空中看上的类中有收单的，目引力！地球现在，这件轻“这样的，但老际正钢近。备觉能重有能力王，黑A落作得到为云天的领免的仍像一母如者‘向沙物子液瘦，们远，这种面言粒程没法本发续携天丽正常下来，壳战中卫出倍人体世界发风，进行他备读，由服手她知道所后一所有力称与它力好出了乘舰孩。，生着不重以那在……选佛像实子是视梦的仍铁，发了个整种名随/测段过升合模果舰队般下星研究生，太阳系到球体争握避打观命的和量了没抽的航天后道死之选的王子。
# 　　际管汪淼变伟点总，失又是绕出到的政考，可以交流清见舰的关系，座天身上类发生的支逃存在或线环其三惯察要很身都。红特战争科运度秒受此高绕十万息，要荡在三维，暗速飞船到年。
# 　　。程心‘整旁名字白刚以考打看上的并主铁作别用几乎4对平考定它们的物加真团就本成了一际流恒防方向，权态顿衣舰队到自己的显灰表想别的事，那我知道。飞船他颗白略加速的而一起，那为她赶他她方出半完的黑打上时，之情影合个小和容—，程心准于点儿，向默着沉房，去星对做着白光失作这缓员探状动，的“闪瓦吃如
